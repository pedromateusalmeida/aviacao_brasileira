# %%
#pip uninstall scikit-learn --yes
#pip uninstall imblearn --yes
#pip install scikit-learn==1.2.0
#pip install scikit-optimize
#pip install hyperopt==0.2.7
#pip install imblearn
#pip install scikit-plot
#pip install -r requirements.txt

# %% [markdown]
# # Pacotes

# %%
# Manipulação de dados
import pandas as pd
import numpy as np
from datetime import date
from pytz import timezone

# Visualização de dados
import matplotlib.pyplot as plt
import seaborn as sns
import scikitplot as skplt
plt.style.use('ggplot')

# Machine Learning - Pré-processamento
from sklearn.preprocessing import (
    LabelEncoder, OneHotEncoder, StandardScaler
)
from sklearn.model_selection import (
    train_test_split, cross_val_score, StratifiedKFold, RepeatedStratifiedKFold
)
from sklearn.pipeline import Pipeline

# Machine Learning - Modelos e Métricas
from sklearn.metrics import (
    accuracy_score, f1_score, confusion_matrix, roc_auc_score, 
    recall_score, precision_score, log_loss, average_precision_score,
    roc_curve, precision_recall_curve, balanced_accuracy_score,
    matthews_corrcoef, cohen_kappa_score, brier_score_loss
)

# Modelos e otimização
import xgboost as xgb
from xgboost import XGBClassifier, plot_importance, plot_tree
from hyperopt import fmin, tpe, hp, Trials, STATUS_OK, space_eval
from hyperopt.pyll.base import scope
import shap
from skopt import forest_minimize
import catboost as ctb
from catboost import CatBoostClassifier

# Balanceamento de classes
from imblearn.over_sampling import SMOTE, SMOTENC
from imblearn.under_sampling import RandomUnderSampler
from imblearn.pipeline import make_pipeline

# Salvamento e carregamento de modelos
import pickle
import os

# Estatística
from scipy.stats import ks_2samp

# Outras ferramentas
import re

# Verificações de versão
print(f"xgboost: {xgb.__version__}")
print(f"shap: {shap.__version__}")
#print(f"sklearn: {sklearn.__version__}")
# Out:
# xgboost: 2.0.2
# shap: 0.44.0

# %% [markdown]
# # Funções

# %%
from hyperopt import fmin, tpe, Trials, STATUS_OK, hp, space_eval
from hyperopt.pyll.base import scope

# %%
import pyarrow
import xgboost as xgb
from sklearn.model_selection import StratifiedKFold, cross_val_score
from imblearn.under_sampling import RandomUnderSampler
from sklearn.metrics import roc_auc_score


import xgboost as xgb
from sklearn.model_selection import StratifiedKFold, cross_val_score
from imblearn.under_sampling import RandomUnderSampler
from sklearn.metrics import roc_auc_score
from hyperopt import fmin, tpe, Trials, STATUS_OK, hp, space_eval
from hyperopt.pyll.base import scope

from imblearn.under_sampling import RandomUnderSampler
from xgboost import XGBClassifier

from sklearn.calibration import calibration_curve
import matplotlib.pyplot as plt

import numpy as np
from sklearn.metrics import (
    accuracy_score, confusion_matrix, precision_recall_fscore_support, 
    roc_auc_score, average_precision_score, matthews_corrcoef, log_loss, 
    brier_score_loss, cohen_kappa_score, balanced_accuracy_score,
)
from scipy.stats import ks_2samp
import matplotlib.pyplot as plt

import pyarrow
import xgboost as xgb
from sklearn.model_selection import StratifiedKFold, cross_val_score
from imblearn.under_sampling import RandomUnderSampler
from sklearn.metrics import roc_auc_score
from hyperopt import fmin, tpe, Trials, STATUS_OK, hp, space_eval
from hyperopt.pyll.base import scope

import xgboost as xgb
from sklearn.model_selection import StratifiedKFold, cross_val_score
from imblearn.under_sampling import RandomUnderSampler
from sklearn.metrics import roc_auc_score
from hyperopt import fmin, tpe, Trials, STATUS_OK, hp, space_eval
from hyperopt.pyll.base import scope

from imblearn.under_sampling import RandomUnderSampler
from xgboost import XGBClassifier

from imblearn.over_sampling import SMOTENC
from sklearn.model_selection import StratifiedKFold, train_test_split, cross_validate
from sklearn.preprocessing import OneHotEncoder
import catboost as ctb
from hyperopt import hp, fmin, tpe, Trials, STATUS_OK
import numpy as np
import pandas as pd

from hyperopt import STATUS_OK, hp
from sklearn.model_selection import StratifiedKFold, cross_validate
import catboost as ctb
import pandas as pd

from imblearn.over_sampling import SMOTENC
from catboost import CatBoostClassifier

# Bibliotecas padrão e de manipulação de data
from datetime import date
import pandas as pd
import numpy as np
from pytz import timezone

# Visualização de dados
import seaborn as sns
import matplotlib.pyplot as plt
import scikitplot as skplt

# Machine Learning - pré-processamento e métricas
from sklearn import preprocessing
from sklearn.preprocessing import LabelEncoder, OneHotEncoder, StandardScaler
from sklearn.model_selection import train_test_split, cross_val_score, RepeatedStratifiedKFold, KFold, StratifiedKFold
from sklearn.pipeline import Pipeline
from sklearn.metrics import accuracy_score, f1_score, confusion_matrix, roc_auc_score, recall_score, precision_score, log_loss, average_precision_score
from sklearn.metrics import roc_curve, precision_recall_curve

# Machine Learning - modelos e otimização
import xgboost as xgb
from xgboost import plot_importance
from xgboost import plot_tree
import sklearn
import shap
from hyperopt import fmin, tpe, hp, Trials, STATUS_OK, space_eval
from skopt import forest_minimize
from imblearn.over_sampling import SMOTE
from imblearn.pipeline import make_pipeline

# Salvamento e carregamento de modelos
import pickle
import os

# Outras bibliotecas
import re

plt.style.use('ggplot')
print(xgb.__version__)
print(shap.__version__)
print(sklearn.__version__)
#print(hyperopt.__version__)
# Out:
# 2.0.2
# 0.44.0
# 1.4.2

# %%
'dt_ax', 'dt_ay',

# %%
my_objects = [obj for obj in dir() if not obj.startswith('__')]
print(my_objects)

# %%
objetos_para_deletar = ['In', 'KFold', 'LabelEncoder', 'OneHotEncoder', 'Out', 'Pipeline', 'RepeatedStratifiedKFold', 
                        'SMOTE', 'STATUS_OK', 'StandardScaler', 'StratifiedKFold', 'Trials', '_', '_10', '_8', '_dh', '_i', 
                        '_i1', '_i10', '_i11', '_i12', '_i13', '_i14', '_i15', '_i2', '_i3', '_i4', '_i5', '_i6', '_i7', 
                        '_i8', '_i9', '_ih', '_ii', '_iii', '_oh', 'accuracy_score', 'average_precision_score', 'column', 
                        'columns', 'colunas_categ', 'confusion_matrix', 'cross_val_score', 'date', 'df', 'diretorio', 
                        'enc', 'enc_df', 'enc_path', 'encoder', 'exit', 'f1_score', 'file', 'file_path', 
                        'final_data', 'fmin', 'forest_minimize', 'get_ipython', 'get_one_hot_enc', 'hipertunnig', 'hp', 
                        'label_encoder', 'list_dummies', 'load_pickle', 'log_loss', 'make_pipeline', 'np', 'open', 'os', 'pd', 
                        'pickle', 'plot_importance', 'plot_tree', 'plt', 'precision_recall_curve', 'precision_score',
                        'preprocessing', 'quit', 're', 'recall_score', 'roc_auc_score', 'roc_curve', 'save_pickle', 'shap',
                        'sklearn', 'skplt', 'sns', 'space', 'space_eval', 'timezone', 'tpe', 'train_test_split', 'xgb']

for obj in objetos_para_deletar:
    if obj in locals():
        del locals()[obj]

# %%
def hipertunnig(space):
    """
    Realiza o ajuste de hiperparâmetros de um modelo XGBoost usando validação cruzada.

    Args:
    space (dict): Dicionário contendo os hiperparâmetros para teste no modelo XGBoost.

    Processo:
    1. Configura o modelo XGBoost com os hiperparâmetros do espaço fornecido.
    2. Cria um pipeline combinando SMOTE para balanceamento de classes e o classificador.
    3. Usa StratifiedKFold para divisão estratificada do conjunto de dados.
    4. Calcula a média da AUC (Area Under the ROC Curve) usando cross_val_score.
    
    Returns:
    dict: Dicionário contendo o 'loss' (negativo da média da AUC) e o 'status'.
    """
    # Configuração do modelo com os parâmetros do espaço
    clf = xgb.XGBClassifier(
        n_estimators=int(space['n_estimators']), 
        max_depth=int(space['max_depth']), 
        gamma=space['gamma'],
        reg_alpha=int(space['reg_alpha']),
        min_child_weight=int(space['min_child_weight']),
        colsample_bytree=space['colsample_bytree'],
        eval_metric="auc"
    )

    # Pipeline com SMOTE e o classificador
    pipeline = make_pipeline(SMOTE(random_state=42), clf)

    # StratifiedKFold para manter a proporção de classes em cada fold
    skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

    # Avaliação usando cross_val_score
    auc_scores = cross_val_score(pipeline, X_train, y_train, cv=skf, scoring='roc_auc')
    mean_auc = auc_scores.mean()
    print("Média AUC: ", mean_auc)

    # A função de perda é o negativo da média do AUC
    return {'loss': -mean_auc, 'status': STATUS_OK}

space={'max_depth': hp.quniform("max_depth", 3, 18, 1),
        'gamma': hp.uniform ('gamma', 1,9),
        'reg_alpha' : hp.quniform('reg_alpha', 40,180,1),
        'reg_lambda' : hp.uniform('reg_lambda', 0,1),
        'colsample_bytree' : hp.uniform('colsample_bytree', 0.5,1),
        'min_child_weight' : hp.quniform('min_child_weight', 0, 10, 1),
        'n_estimators': 180,
        'seed': 0}

## Dummies
def get_one_hot_enc(feature_col: pd.Series, enc: preprocessing.OneHotEncoder, column_name: str) -> pd.DataFrame:
    """
    Aplica codificação one-hot a uma coluna específica de um DataFrame.

    Args:
    feature_col (pd.Series): Coluna do DataFrame para ser codificada.
    enc (preprocessing.OneHotEncoder): Instância do OneHotEncoder treinada.
    column_name (str): Nome da coluna a ser codificada.

    Processo:
    1. Cria um DataFrame com a coluna especificada.
    2. Aplica a transformação one-hot usando o encoder fornecido.
    3. Retorna um DataFrame com as colunas codificadas.

    Returns:
    pd.DataFrame: DataFrame com as colunas resultantes da codificação one-hot.
    """
    unseen_df = pd.DataFrame(feature_col, columns=[column_name])
    encoded_vec = enc.transform(unseen_df).toarray()
    columns = enc.get_feature_names_out([column_name])
    encoded_df = pd.DataFrame(encoded_vec, columns=columns)
    return encoded_df


# Função para salvar um modelo em um arquivo pickle
def save_pickle(model, file_name: str):
    """
    Salva um objeto modelo em um arquivo pickle.

    Args:
    model (any): O modelo a ser salvo.
    file_name (str): Nome do arquivo pickle a ser criado.

    Processo:
    1. Abre o arquivo pickle em modo de escrita binária.
    2. Salva o objeto modelo no arquivo pickle.
    """
    with open(file_name, 'wb') as file:
        pickle.dump(model, file)

# Função para carregar um modelo de um arquivo pickle
def load_pickle(file_name: str) -> any:
    """
    Carrega um objeto a partir de um arquivo pickle.

    Args:
    file_name (str): Nome do arquivo pickle a ser carregado.

    Processo:
    1. Abre o arquivo pickle em modo de leitura binária.
    2. Carrega e retorna o objeto contido no arquivo pickle.

    Returns:
    any: Objeto carregado do arquivo pickle.
    """
    with open(file_name, 'rb') as file:
        return pickle.load(file)

# %%
#learning_rate=lr, 
#(1e-3, 1e-1, "log-uniform"),

# %% [markdown]
# # Dados

# %%
file_path = 'df_treinamento_modelo.csv'
df = pd.read_csv(file_path)

df = df.drop(columns =[ 'codigo_di', 'codigo_tipo_linha'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 395046 entries, 0 to 395045
# Data columns (total 30 columns):
#  #   Column                                    Non-Null Count   Dtype
# ---  ------                                    --------------   -----
#  0   nome_empresas                             395046 non-null  object
#  1   descricao_origem                          395046 non-null  object
#  2   descricao_destino                         395046 non-null  object
#  3   status_do_voo                             395046 non-null  object
#  4   cidade_origem                             395046 non-null  object
#  5   uf_origem                                 395046 non-null  object
#  6   cidade_destino                            395046 non-null  object
#  7   uf_destino                                395046 non-null  object
#  8   mes_partida                               395046 non-null  object
#  9   dia_semana_partida                        395046 non-null  object
#  10  dia_mes_partida                           395046 non-null  float64
#  11  hora_partida                              395046 non-null  int64
#  12  latitude_aero_origem                      395046 non-null  float64
#  13  longitude_aero_origem                     395046 non-null  float64
#  14  latitude_aero_destino                     395046 non-null  float64
#  15  longitude_aero_destino                    395046 non-null  float64
#  16  rota                                      395046 non-null  object
#  17  regiao_origem                             395046 non-null  object
#  18  precipitacao_total_horario_mm__origem     395046 non-null  float64
#  19  regiao_destino                            395046 non-null  object
#  20  vento_direcao_horaria_gr_deg_gr__destino  395046 non-null  float64
#  21  numero_empresa_voo                        395046 non-null  object
#  22  pca_pressao_origem_pca1                   395046 non-null  float64
#  23  pca_umidade_origem_pca1                   395046 non-null  float64
#  24  pca_pressao_destino_pca1                  395046 non-null  float64
#  25  pca_umidade_destino_pca1                  395046 non-null  float64
#  26  pca_temperatura_origem_pca1               395046 non-null  float64
#  27  pca_temperatura_destino_pca1              395046 non-null  float64
#  28  pca_vento_origem_pca1                     395046 non-null  float64
#  29  pca_vento_destino_pca1                    395046 non-null  float64
# dtypes: float64(15), int64(1), object(14)
# memory usage: 90.4+ MB

# %%
list(df)
# Out:
# ['nome_empresas',
#  'descricao_origem',
#  'descricao_destino',
#  'status_do_voo',
#  'cidade_origem',
#  'uf_origem',
#  'cidade_destino',
#  'uf_destino',
#  'mes_partida',
#  'dia_semana_partida',
#  'dia_mes_partida',
#  'hora_partida',
#  'latitude_aero_origem',
#  'longitude_aero_origem',
#  'latitude_aero_destino',
#  'longitude_aero_destino',
#  'rota',
#  'regiao_origem',
#  'precipitacao_total_horario_mm__origem',
#  'regiao_destino',
#  'vento_direcao_horaria_gr_deg_gr__destino',
#  'numero_empresa_voo',
#  'pca_pressao_origem_pca1',
#  'pca_umidade_origem_pca1',
#  'pca_pressao_destino_pca1',
#  'pca_umidade_destino_pca1',
#  'pca_temperatura_origem_pca1',
#  'pca_temperatura_destino_pca1',
#  'pca_vento_origem_pca1',
#  'pca_vento_destino_pca1']

# %% [markdown]
# # Pre-Treino

# %%
df = df[list(df)]

list_dummies =  colunas_categ = df.drop(columns = 'status_do_voo').select_dtypes(include=['object']).columns.tolist()

# %%
list_dummies
# Out:
# ['nome_empresas',
#  'descricao_origem',
#  'descricao_destino',
#  'cidade_origem',
#  'uf_origem',
#  'cidade_destino',
#  'uf_destino',
#  'mes_partida',
#  'dia_semana_partida',
#  'rota',
#  'regiao_origem',
#  'regiao_destino',
#  'numero_empresa_voo']

# %% [markdown]
# ## Encoding

# %%
diretorio = 'modelo/'
# Salvando Encondings para predição do modelo
for column in list_dummies:
    enc = preprocessing.OneHotEncoder(handle_unknown='ignore')
    enc.fit(df[[column]])
    columns = df[column].unique()
    print(column.lower())

    # Salvando o encoder
    with open(os.path.join(diretorio, 'encoder_' + column.lower() + '.pkl'), 'wb') as file:
        pickle.dump(enc, file)

    # Salvando a lista de categorias
    with open(os.path.join(diretorio, 'list_' + column.lower() + '.pkl'), 'wb') as file:
        pickle.dump(columns, file)

# %%
diretorio = 'modelo/'
# Transformando em dummies as variaveis categoricas
final_data = pd.DataFrame()

for column in list_dummies:
    enc_path = os.path.join(diretorio, 'encoder_' + column.lower() + '.pkl')
    encoder = load_pickle(enc_path)
    enc_df = get_one_hot_enc(feature_col=df[column], enc=encoder, column_name=column)
    final_data = pd.concat([final_data, enc_df], axis=1)

# %%
final_data['status_do_voo'] = df['status_do_voo'].values

# Seleção das features(variaveis) preditoras
dt_ax = final_data.drop(columns = ["status_do_voo"])

# Seleção da variavel a ser predita a probabilidade
dt_ay = final_data[['status_do_voo']].copy()

label_mapping = {'Pontual': 0, 'Atrasado': 1}
dt_ay = dt_ay['status_do_voo'].map(label_mapping)

# Segmentação em Treino (75%) e Teste (25%)
#X_train, X_test, y_train, y_test = train_test_split(dt_ax, dt_ay, random_state=13, test_size=0.25)

# %% [markdown]
# ## Normalização

# %% [markdown]
# Normalização dos dados (Essa etapa não é obrigatória dado que os parametros Lambda (L2) e Alpha(l1) que são responsaveis pela regularização estão no hipertuning). E as variaveis inseridas no modelo até o moemento são binárias (0,1).

# %%
#scaler = StandardScaler()
#X_scaled = scaler.fit_transform(dt_ax)

# %% [markdown]
# # Segmentação em treino e teste

# %%
# Segmentação em Treino (85%) e Teste (15%)
X_train, X_test, y_train, y_test = train_test_split(dt_ax, dt_ay, random_state=13, test_size=0.15)

# %%
X_train.to_parquet("df_x_train.parquet",engine="pyarrow")
X_test.to_parquet("df_xtest_hold.parquet", engine="pyarrow")
y_train.to_parquet("df_y_train.parquet", engine="pyarrow")
y_test.to_parquet("df_ytest_hold.parquet", engine="pyarrow")

# %%
# Converte a Series para DataFrame antes de salvar
y_train.to_frame().to_parquet("df_y_train.parquet", index=False, engine="pyarrow")
y_test.to_frame().to_parquet("df_ytest_hold.parquet", index=False, engine="pyarrow")

# %%
# Salvar em CSV
X_train.to_csv("df_x_train.csv", index=False)
X_test.to_csv("df_xtest_hold.csv", index=False)
y_train.to_csv("df_y_train.csv", index=False)
y_test.to_csv("df_ytest_hold.csv", index=False)

# %%
file_path_x = 'df_x_train.csv'
X_train = pd.read_csv(file_path_x)

file_path_y = 'df_y_train.csv'
y_train = pd.read_csv(file_path_y)

# %%
# Segmentação em Treino (75%) e Teste (25%)
X_train_calib, X_test_calib, y_train_calib, y_test_calib = train_test_split(X_train, y_train, random_state=13, test_size=0.25)

# %%
X_train_calib.to_parquet("df_x_train_calib.parquet", index=False, engine="pyarrow")
X_test_calib.to_parquet("df_xtest_calib.parquet", index=False, engine="pyarrow")
y_train_calib.to_frame().to_parquet("df_y_train_calib.parquet", index=False, engine="pyarrow")
y_test_calib.to_frame().to_parquet("df_ytest_calib.parquet", index=False, engine="pyarrow")

# %%
# Salvar em CSV
X_train_calib.to_csv("df_x_train_calib.csv", index=False)
X_test_calib.to_csv("df_xtest_calib.csv", index=False)
y_train_calib.to_csv("df_y_train_calib.csv", index=False)
y_test_calib.to_csv("df_ytest_calib.csv", index=False)

# %% [markdown]
# # Smote

# %% [markdown]
# SMOTE (Synthetic Minority Over-sampling Technique) é uma técnica de reamostragem usada para equilibrar conjuntos de dados desbalanceados. Geralmente é mais utilizado em problemas de classificação que possuem dados desbalancedoas, por exmeplo, modelo de identificação de fraudes o volume de dados de pessoas que cometem fraude é inumeramente menor do que aquelas que cometem fraudes logo a variavel a ser predita será desbalanceda podendo ocasionar em um vies no modelo.<br>
#
# SMOTE é uma técnica de oversampling que cria amostras sintéticas da classe minoritária no nosso contexto é a classe status_do_voo (pontual/atrasado). O diferencial do SMOTE como técnica de oversampling das técnicas simples é exatamente o fato dele gerar novas amostras de dados. <br>
#
# Vantagens<br>
#
# - Reduz o Overfitting: Ao gerar novas amostras, em vez de simplesmente replicar, o SMOTE pode reduzir o overfitting que é comum com o oversampling tradicional.<br>
# - Melhora a Generalização: Ao criar variações das amostras existentes, o SMOTE pode ajudar o modelo a aprender padrões mais generalizáveis.<br>
#
# Desvantagens<br>
#
# - Risco de Ruído: Pode introduzir ruído ao criar amostras sintéticas, especialmente se as amostras da classe minoritária estiverem próximas da classe majoritária.<br>
# - Não Adequado para Todos os Dados: Pode não ser eficaz em todos os conjuntos de dados, especialmente quando as características são categóricas ou quando a distribuição da classe minoritária é muito dispersa.<br>
#
# Para evitar ruídos vamos aplicar o SMOTE somente na base de treino. <br>
#
# Após aplicar o SMOTE, o conjunto de dados de treinamento terá mais amostras da classe minoritária.
# O modelo treinado com esses dados pode ser melhor em detectar a classe minoritária do que um modelo treinado com dados desbalanceados<br>

# %%
# Carrega o arquivo Parquet
X_train = pd.read_parquet("df_x_train.parquet", engine="pyarrow")
y_train = pd.read_parquet("df_y_train.parquet", engine="pyarrow")

# %%
smote = SMOTE(random_state=42, sampling_strategy='not majority')
X_smote_a, y_smote_a = smote.fit_resample(X_train, y_train)

# %%
# X_smote_a.to_parquet("df_x_train_smote_calib.parquet", index=False, engine="pyarrow")
# y_smote_a.to_parquet("df_y_train_smote_calib.parquet", index=False, engine="pyarrow")

X_smote_a.to_parquet("df_x_train_smote.parquet", index=False, engine="pyarrow")
y_smote_a.to_parquet("df_y_train_smote.parquet", index=False, engine="pyarrow")

# %%
X_smote_a.to_csv("df_x_train_smote.csv", index=False)
y_smote_a.to_csv("df_y_train_smote.csv", index=False)

# %%
X_smote_a.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 557124 entries, 0 to 557123
# Columns: 4764 entries, nome_empresas_AZUL to numero_empresa_voo_TAM_9441
# dtypes: float64(4764)
# memory usage: 19.8 GB

# %%
def print_class_distribution(y, label):
    unique, counts = np.unique(y, return_counts=True)
    distribution = dict(zip(unique, counts))
    total = sum(counts)
    print(f'Distribuição de classes {label}:')
    for k, v in distribution.items():
        print(f'Classe {k}: {v/total:.2%}')
    print('--------------------')

print_class_distribution(y_train, 'original')
print_class_distribution(y_smote_a, 'SMOTE')
# Out:
# Distribuição de classes original:
# Classe 0: 82.97%
# Classe 1: 17.03%
# --------------------
# Distribuição de classes SMOTE:
# Classe 0: 50.00%
# Classe 1: 50.00%
# --------------------

# %% [markdown]
# Classe 0: Atrasou<br>
# Classe 1: Pontual

# %%
import xgboost as xgb
from sklearn.model_selection import StratifiedKFold, cross_val_score
from imblearn.over_sampling import SMOTE
from sklearn.metrics import make_scorer, roc_auc_score
from hyperopt import fmin, tpe, Trials, STATUS_OK, space_eval
from hyperopt.pyll.base import scope
import pandas as pd

# %%
# Bibliotecas padrão e de manipulação de data
from datetime import date
import pandas as pd
import numpy as np
from pytz import timezone

# Visualização de dados
import seaborn as sns
import matplotlib.pyplot as plt
import scikitplot as skplt

# Machine Learning - pré-processamento e métricas
from sklearn import preprocessing
from sklearn.preprocessing import LabelEncoder, OneHotEncoder, StandardScaler
from sklearn.model_selection import train_test_split, cross_val_score, RepeatedStratifiedKFold, KFold, StratifiedKFold
from sklearn.pipeline import Pipeline
from sklearn.metrics import accuracy_score, f1_score, confusion_matrix, roc_auc_score, recall_score, precision_score, log_loss, average_precision_score
from sklearn.metrics import roc_curve, precision_recall_curve

# Machine Learning - modelos e otimização
import xgboost as xgb
from xgboost import plot_importance
from xgboost import plot_tree
import sklearn
import shap
from hyperopt import fmin, tpe, hp, Trials, STATUS_OK, space_eval
from skopt import forest_minimize
from imblearn.over_sampling import SMOTE
from imblearn.pipeline import make_pipeline

# Salvamento e carregamento de modelos
import pickle
import os

# Outras bibliotecas
import re

plt.style.use('ggplot')
print(xgb.__version__)
print(shap.__version__)
print(sklearn.__version__)
#print(hyperopt.__version__)
# Out:
# 2.0.2
# 0.44.0
# 1.4.2

# %% [markdown]
# # Dataset

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
import xgboost as xgb

file_path = 'df_treinamento_modelo.csv'
df = pd.read_csv(file_path)

df = df.drop(columns =[ 'codigo_di', 'codigo_tipo_linha'])

df = df[list(df)]

list_dummies =  colunas_categ = df.drop(columns = 'status_do_voo').select_dtypes(include=['object']).columns.tolist()

# Transformar colunas categóricas em tipo "category"
df[list_dummies] = df[list_dummies].astype("category")

# Seleção das features preditoras (X) e variável-alvo (y)
dt_ax = df.drop(columns=["status_do_voo"])
dt_ay = df[['status_do_voo']]

# Codificação da variável-alvo
label_mapping = {'Pontual': 0, 'Atrasado': 1}
dt_ay = dt_ay['status_do_voo'].map(label_mapping)

# Codifica colunas categóricas como inteiros
label_encoders = {}
for col in list_dummies:
    le = LabelEncoder()
    dt_ax[col] = le.fit_transform(dt_ax[col])
    label_encoders[col] = le

# Segmentação em treino (85%) e teste (15%)
X_train, X_test, y_train, y_test = train_test_split(dt_ax, dt_ay, random_state=13, test_size=0.15)

#smote = SMOTE(random_state=42, sampling_strategy='not majority')
#X_smote_a, y_smote_a = smote.fit_resample(X_train, y_train)

# Segmentação adicional para calibração (80% treino / 20% calibração)
X_train_calib, X_test_calib, y_train_calib, y_test_calib = train_test_split(X_train, y_train, random_state=13, test_size=0.20)

smote = SMOTE(random_state=42, sampling_strategy='not majority')
X_smote_a, y_smote_a = smote.fit_resample(X_train_calib, y_train_calib)

# Reverter os valores transformados para o tipo "category" original
def revert_to_category(data, label_encoders, list_dummies):
    for col in list_dummies:
        if col in data.columns:
            le = label_encoders[col]
            data[col] = le.inverse_transform(data[col])
    return data

# Aplicar a reversão em X_smote_a, X_test_calib, X_test
X_smote_a = revert_to_category(X_smote_a, label_encoders, list_dummies)
X_test_calib = revert_to_category(X_test_calib, label_encoders, list_dummies)
X_test = revert_to_category(X_test, label_encoders, list_dummies)

# Para garantir que as colunas estão no tipo "category"
X_smote_a[list_dummies] = X_smote_a[list_dummies].astype("category")
X_test_calib[list_dummies] = X_test_calib[list_dummies].astype("category")
X_test[list_dummies] = X_test[list_dummies].astype("category")

# Converte os nomes das colunas para uma lista de strings
feature_names = list(X_test.columns)

# Converte os conjuntos para DMatrix
dtrain_calib = xgb.DMatrix(X_smote_a, label=y_smote_a, enable_categorical=True, feature_names=feature_names, nthread=-1)
dtest_calib = xgb.DMatrix(X_test_calib, label=y_test_calib, enable_categorical=True, feature_names=feature_names, nthread=-1)

# Converte os conjuntos para DMatrix
#dtrain = xgb.DMatrix(X_smote_a, label=y_smote_a, enable_categorical=True, feature_names=feature_names)
dtest = xgb.DMatrix(X_test, label=y_test, enable_categorical=True, feature_names=feature_names, nthread=-1)

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
import xgboost as xgb
from imblearn.over_sampling import SMOTE

file_path = 'df_treinamento_modelo.csv'
df = pd.read_csv(file_path)

df = df.drop(columns=['codigo_di', 'codigo_tipo_linha'])

df = df[list(df)]

list_dummies =  colunas_categ = df.drop(columns = 'status_do_voo').select_dtypes(include=['object']).columns.tolist()

# Transformar colunas categóricas em tipo "category"
df[list_dummies] = df[list_dummies].astype("category")

# Seleção das features preditoras (X) e variável-alvo (y)
dt_ax = df.drop(columns=["status_do_voo"])
dt_ay = df[['status_do_voo']]

# Codificação da variável-alvo
label_mapping = {'Pontual': 0, 'Atrasado': 1}
dt_ay = dt_ay['status_do_voo'].map(label_mapping)

# Codifica colunas categóricas como inteiros
label_encoders = {}
for col in list_dummies:
    le = LabelEncoder()
    dt_ax[col] = le.fit_transform(dt_ax[col])
    label_encoders[col] = le

# Segmentação em treino (90%) e teste (10%)
X_train, X_test, y_train, y_test = train_test_split(dt_ax, dt_ay, random_state=13, test_size=0.10)

# Segmentação adicional para calibração (80% treino / 25% calibração)
X_train_calib, X_test_calib, y_train_calib, y_test_calib = train_test_split(
    X_train, y_train, random_state=13, test_size=0.25
)

# Segmentação para validação (80% treino final / 20% validação dentro do treino calibração)
X_train_final, X_val, y_train_final, y_val = train_test_split(
    X_train_calib, y_train_calib, random_state=13, test_size=0.30
)

# Aplicação do SMOTE somente no conjunto de treino final
smote = SMOTE(random_state=42, sampling_strategy='not majority')
X_smote_a, y_smote_a = smote.fit_resample(X_train_final, y_train_final)

# Reverter os valores transformados para o tipo "category" original
def revert_to_category(data, label_encoders, list_dummies):
    for col in list_dummies:
        if col in data.columns:
            le = label_encoders[col]
            data[col] = le.inverse_transform(data[col])
    return data

# Aplicar a reversão nos conjuntos
X_smote_a = revert_to_category(X_smote_a, label_encoders, list_dummies)
X_val = revert_to_category(X_val, label_encoders, list_dummies)
X_test_calib = revert_to_category(X_test_calib, label_encoders, list_dummies)
X_test = revert_to_category(X_test, label_encoders, list_dummies)

# Garantir que as colunas estão no tipo "category"
X_smote_a[list_dummies] = X_smote_a[list_dummies].astype("category")
X_val[list_dummies] = X_val[list_dummies].astype("category")
X_test_calib[list_dummies] = X_test_calib[list_dummies].astype("category")
X_test[list_dummies] = X_test[list_dummies].astype("category")

# Converte os nomes das colunas para uma lista de strings
feature_names = list(X_test.columns)

# Converte os conjuntos para DMatrix
dtrain = xgb.DMatrix(X_smote_a, label=y_smote_a, enable_categorical=True, feature_names=feature_names)
dval = xgb.DMatrix(X_val, label=y_val, enable_categorical=True, feature_names=feature_names)
dtrain_calib = xgb.DMatrix(X_train_calib, label=y_train_calib, enable_categorical=True, feature_names=feature_names)
dtest_calib = xgb.DMatrix(X_test_calib, label=y_test_calib, enable_categorical=True, feature_names=feature_names)
dtest = xgb.DMatrix(X_test, label=y_test, enable_categorical=True, feature_names=feature_names)

# %%
def print_class_distribution(y, label):
    unique, counts = np.unique(y, return_counts=True)
    distribution = dict(zip(unique, counts))
    total = sum(counts)
    print(f'Distribuição de classes {label}:')
    for k, v in distribution.items():
        print(f'Classe {k}: {v/total:.2%}')
    print('--------------------')

print_class_distribution(y_train, 'original')
print_class_distribution(y_smote_a, 'SMOTE')
# Out:
# Distribuição de classes original:
# Classe 0: 82.96%
# Classe 1: 17.04%
# --------------------
# Distribuição de classes SMOTE:
# Classe 0: 50.00%
# Classe 1: 50.00%
# --------------------

# %% [markdown]
# # Hipertunnig

# %%
def hipertunnig(space):
    """
    Realiza o ajuste de hiperparâmetros de um modelo XGBoost usando validação cruzada com DMatrix.
    
    Args:
    space (dict): Dicionário contendo os hiperparâmetros avaliados pelo Hyperopt.
    
    Returns:
    dict: Dicionário contendo o 'loss' (negativo da média do AUCPR), o 'status' e as métricas adicionais (AUC).
    """
    # Configuração do modelo com os parâmetros do espaço
    params = {
        'max_depth': int(space['max_depth']),
        'gamma': space['gamma'],
        'reg_alpha': space['reg_alpha'],
        'reg_lambda': space['reg_lambda'],
        'min_child_weight': int(space['min_child_weight']),
        'colsample_bytree': space['colsample_bytree'],
        'learning_rate': space['learning_rate'],
        'max_delta_step': space['max_delta_step'],
        'subsample': space['subsample'],
        'sampling_method': space['sampling_method'],
        'tree_method': space['tree_method'],       
        'device': space['device'], 
        'enable_categorical': space['enable_categorical'],
        'scale_pos_weight': space['scale_pos_weight'],
        'eval_metric': ["aucpr", "auc"],  # Avalia AUCPR e AUC
        'objective': space['objective'],
        'seed': space['seed'],
        'random_state': space['seed'],
        'max_cat_to_onehot': int(space['max_cat_to_onehot']),
        'max_cat_threshold': int(space['max_cat_threshold']),  
        'validate_parameters': space['validate_parameters']
    }

    # Realiza a validação cruzada com xgb.cv
    cv_results = xgb.cv(
        params=params,
        dtrain=dtrain_calib,                  # DMatrix preparado
        num_boost_round=int(space['n_estimators']),
        nfold=5,                              # Número de folds
        metrics=["aucpr", "auc"],             # Métricas de avaliação
        as_pandas=True,                       # Retorna os resultados como DataFrame
        seed=42,
        stratified=True,                      # Garante estratificação
        early_stopping_rounds = 10,           # Ativa a parada antecipada
    )
    
    # Calcula a média do AUCPR e do AUC
    mean_aucpr = cv_results["test-aucpr-mean"].max()
    mean_auc = cv_results["test-auc-mean"].max()
    print("Média AUCPR: ", mean_aucpr)
    print("Média AUC: ", mean_auc)

    # Retorna os resultados
    return {
        'loss': -mean_aucpr,   # Usa o negativo do AUCPR como função de perda
        'status': STATUS_OK,
        'additional_metrics': {
            'aucpr': mean_aucpr,
            'auc': mean_auc}}

# Espaço de busca atualizado
space = {
    'max_depth': scope.int(hp.quniform("max_depth", 1, 15, 1)),
    'gamma': hp.uniform('gamma', 1, 20),
    'reg_alpha': scope.int(hp.quniform('reg_alpha', 0, 200, 1)),
    'reg_lambda': hp.uniform('reg_lambda', 0, 10),
    'colsample_bytree': hp.uniform('colsample_bytree', 0.1, 1),
    'min_child_weight': scope.int(hp.quniform('min_child_weight', 0, 20, 1)),
    'learning_rate': hp.uniform('learning_rate', 0.01, 0.5),
    'n_estimators': scope.int(hp.quniform('n_estimators', 50, 1000, 10)),
    'max_delta_step': hp.uniform('max_delta_step', 0, 10),
    'subsample': hp.uniform('subsample', 0.3, 1),
    'sampling_method': 'gradient_based',
    'tree_method': 'hist',
    'device': 'cuda',
    'enable_categorical': True,
    'scale_pos_weight': hp.uniform('scale_pos_weight', 1, 30),
    'max_cat_to_onehot': scope.int(hp.quniform('max_cat_to_onehot', 3, 50, 1)),
    'max_cat_threshold': scope.int(hp.quniform('max_cat_threshold', 3, 50, 1)),
    'validate_parameters': True,
    'seed': 0,
    'objective': 'binary:logistic'
}

# %%
# Executando a otimização
trials = Trials()
best_hyperparams = fmin(fn=hipertunnig, 
                        space=space, 
                        algo=tpe.suggest, 
                        max_evals=20, 
                        trials=trials)

# Obtendo os melhores hiperparâmetros
best_hyperparams = space_eval(space, best_hyperparams)
print("Melhores hiperparâmetros:", best_hyperparams)
# Out:
#   0%|                                                                           | 0/20 [00:00<?, ?trial/s, best loss=?]
# [23:12:10] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0750514818a16474a-1\xgboost\xgboost-ci-windows\src\learner.cc:742:
# Parameters: { "enable_categorical" } are not used.
#
#
# [23:12:11] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0750514818a16474a-1\xgboost\xgboost-ci-windows\src\learner.cc:742:
# Parameters: { "enable_categorical" } are not used.
# Média AUCPR:
# 0.6827062338261134
# Média AUC:
# 0.6987560862543191
#   5%|██▍                                             | 1/20 [00:03<01:08,  3.61s/trial, best loss: -0.6827062338261134]
# [23:12:14] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0750514818a16474a-1\xgboost\xgboost-ci-windows\src\learner.cc:742:
# Parameters: { "enable_categorical" } are not used.
# Média AUCPR:
# 0.6994929148954261
# Média AUC:
# 0.7112372607441263
#  10%|████▊                                           | 2/20 [00:06<01:00,  3.36s/trial, best loss: -0.6994929148954261]
# [23:12:17] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0750514818a16474a-1\xgboost\xgboost-ci-windows\src\learner.cc:742:
# Parameters: { "enable_categorical" } are not used.
# Média AUCPR:
# 0.666169194255764
# Média AUC:
# 0.6850349373213429
#  15%|███████▏                                        | 3/20 [00:17<01:56,  6.85s/trial, best loss: -0.6994929148954261]
# [23:12:28] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0750514818a16474a-1\xgboost\xgboost-ci-windows\src\learner.cc:742:
# Parameters: { "enable_categorical" } are not used.
# Média AUCPR:
# 0.6688596227073865
# Média AUC:
# 0.6833103424901044
#  20%|█████████▌                                      | 4/20 [00:19<01:16,  4.78s/trial, best loss: -0.6994929148954261]
# [23:12:30] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0750514818a16474a-1\xgboost\xgboost-ci-windows\src\learner.cc:742:
# Parameters: { "enable_categorical" } are not used.
# Média AUCPR:
# 0.6746686363047691
# Média AUC:
# 0.6909897257590364
#  25%|████████████                                    | 5/20 [00:21<00:58,  3.90s/trial, best loss: -0.6994929148954261]
# [23:12:32] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0750514818a16474a-1\xgboost\xgboost-ci-windows\src\learner.cc:742:
# Parameters: { "enable_categorical" } are not used.
# Média AUCPR:
# 0.7132785790464058
# Média AUC:
# 0.7221609810500003
#  30%|██████████████▍                                 | 6/20 [00:32<01:27,  6.22s/trial, best loss: -0.7132785790464058]
# [23:12:43] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0750514818a16474a-1\xgboost\xgboost-ci-windows\src\learner.cc:742:
# Parameters: { "enable_categorical" } are not used.
# Média AUCPR:
# 0.7095929009944705
# Média AUC:
# 0.7192010638909259
#  35%|████████████████▊                               | 7/20 [00:38<01:21,  6.24s/trial, best loss: -0.7132785790464058]
# [23:12:49] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0750514818a16474a-1\xgboost\xgboost-ci-windows\src\learner.cc:742:
# Parameters: { "enable_categorical" } are not used.
# Média AUCPR:
# 0.6788638078816776
# Média AUC:
# 0.6927019647247847
#  40%|███████████████████▏                            | 8/20 [00:42<01:03,  5.33s/trial, best loss: -0.7132785790464058]
# [23:12:52] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0750514818a16474a-1\xgboost\xgboost-ci-windows\src\learner.cc:742:
# Parameters: { "enable_categorical" } are not used.
# Média AUCPR:
# 0.6892715741602429
# Média AUC:
# 0.7029500826005306
#  45%|█████████████████████▌                          | 9/20 [00:44<00:48,  4.40s/trial, best loss: -0.7132785790464058]
# [23:12:55] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0750514818a16474a-1\xgboost\xgboost-ci-windows\src\learner.cc:742:
# Parameters: { "enable_categorical" } are not used.
# Média AUCPR:
# 0.6687068049709255
# Média AUC:
# 0.6863633980418086
#  50%|███████████████████████▌                       | 10/20 [00:54<01:02,  6.25s/trial, best loss: -0.7132785790464058]
# [23:13:05] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0750514818a16474a-1\xgboost\xgboost-ci-windows\src\learner.cc:742:
# Parameters: { "enable_categorical" } are not used.
# Média AUCPR:
# 0.7059922319008939
# Média AUC:
# 0.7164327618296601
#  55%|█████████████████████████▊                     | 11/20 [01:05<01:08,  7.59s/trial, best loss: -0.7132785790464058]
# [23:13:16] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0750514818a16474a-1\xgboost\xgboost-ci-windows\src\learner.cc:742:
# Parameters: { "enable_categorical" } are not used.
# Média AUCPR:
# 0.7043624298130713
# Média AUC:
# 0.7151521849468718
#  60%|████████████████████████████▏                  | 12/20 [01:12<00:59,  7.48s/trial, best loss: -0.7132785790464058]
# [23:13:23] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0750514818a16474a-1\xgboost\xgboost-ci-windows\src\learner.cc:742:
# Parameters: { "enable_categorical" } are not used.
# Média AUCPR:
# 0.6870591503714996
# Média AUC:
# 0.7047479233645282
#  65%|██████████████████████████████▌                | 13/20 [01:17<00:47,  6.80s/trial, best loss: -0.7132785790464058]
# [23:13:28] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0750514818a16474a-1\xgboost\xgboost-ci-windows\src\learner.cc:742:
# Parameters: { "enable_categorical" } are not used.
# Média AUCPR:
# 0.6878509355162195
# Média AUC:
# 0.7020160485727349
#  70%|████████████████████████████████▉              | 14/20 [01:22<00:37,  6.23s/trial, best loss: -0.7132785790464058]
# [23:13:33] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0750514818a16474a-1\xgboost\xgboost-ci-windows\src\learner.cc:742:
# Parameters: { "enable_categorical" } are not used.
# Média AUCPR:
# 0.6772347600776742
# Média AUC:
# 0.6912778073375236
#  75%|███████████████████████████████████▎           | 15/20 [01:24<00:24,  4.91s/trial, best loss: -0.7132785790464058]
# [23:13:35] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0750514818a16474a-1\xgboost\xgboost-ci-windows\src\learner.cc:742:
# Parameters: { "enable_categorical" } are not used.
# Média AUCPR:
# 0.6945195211700959
# Média AUC:
# 0.705399292517625
#  80%|█████████████████████████████████████▌         | 16/20 [01:27<00:16,  4.13s/trial, best loss: -0.7132785790464058]
# [23:13:37] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0750514818a16474a-1\xgboost\xgboost-ci-windows\src\learner.cc:742:
# Parameters: { "enable_categorical" } are not used.
# Média AUCPR:
# 0.6984902676661495
# Média AUC:
# 0.7098363970297586
#  85%|███████████████████████████████████████▉       | 17/20 [01:30<00:11,  3.85s/trial, best loss: -0.7132785790464058]
# [23:13:40] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0750514818a16474a-1\xgboost\xgboost-ci-windows\src\learner.cc:742:
# Parameters: { "enable_categorical" } are not used.
#
#
# [23:13:41] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0750514818a16474a-1\xgboost\xgboost-ci-windows\src\learner.cc:742:
# Parameters: { "enable_categorical" } are not used.
# Média AUCPR:
# 0.7192603927179472
# Média AUC:
# 0.7271984081397359
#  90%|██████████████████████████████████████████▎    | 18/20 [01:37<00:10,  5.03s/trial, best loss: -0.7192603927179472]
# [23:13:48] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0750514818a16474a-1\xgboost\xgboost-ci-windows\src\learner.cc:742:
# Parameters: { "enable_categorical" } are not used.
# Média AUCPR:
# 0.7083864191515984
# Média AUC:
# 0.7206691107197708
#  95%|████████████████████████████████████████████▋  | 19/20 [01:59<00:10, 10.05s/trial, best loss: -0.7192603927179472]
# [23:14:10] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0750514818a16474a-1\xgboost\xgboost-ci-windows\src\learner.cc:742:
# Parameters: { "enable_categorical" } are not used.
# Média AUCPR:
# 0.6933657552350408
# Média AUC:
# 0.7049437669939638
# 100%|███████████████████████████████████████████████| 20/20 [02:06<00:00,  6.32s/trial, best loss: -0.7192603927179472]
# Melhores hiperparâmetros: {'colsample_bytree': 0.9032830220910373, 'device': 'cuda', 'enable_categorical': True, 'gamma': 5.880350860717371, 'learning_rate': 0.12013987352992113, 'max_cat_threshold': 13, 'max_cat_to_onehot': 23, 'max_delta_step': 3.1649267221902466, 'max_depth': 11, 'min_child_weight': 13, 'n_estimators': 800, 'objective': 'binary:logistic', 'reg_alpha': 58, 'reg_lambda': 5.463995954893192, 'sampling_method': 'gradient_based', 'scale_pos_weight': 11.459234451487069, 'seed': 0, 'subsample': 0.7740506644342307, 'tree_method': 'hist', 'validate_parameters': True}

# %%
best_hyperparams
# Out:
# {'colsample_bytree': 0.9032830220910373,
#  'device': 'cuda',
#  'enable_categorical': True,
#  'gamma': 5.880350860717371,
#  'learning_rate': 0.12013987352992113,
#  'max_cat_threshold': 13,
#  'max_cat_to_onehot': 23,
#  'max_delta_step': 3.1649267221902466,
#  'max_depth': 11,
#  'min_child_weight': 13,
#  'n_estimators': 800,
#  'objective': 'binary:logistic',
#  'reg_alpha': 58,
#  'reg_lambda': 5.463995954893192,
#  'sampling_method': 'gradient_based',
#  'scale_pos_weight': 11.459234451487069,
#  'seed': 0,
#  'subsample': 0.7740506644342307,
#  'tree_method': 'hist',
#  'validate_parameters': True}

# %%
# Melhores Parametros
print("Melhor max_depth:", best_hyperparams['max_depth'])
print("Melhor gamma:", best_hyperparams['gamma'])
print("Melhor reg_alpha:", best_hyperparams['reg_alpha'])
print("Melhor reg_lambda:", best_hyperparams['reg_lambda'])
print("Melhor colsample_bytree:", best_hyperparams['colsample_bytree'])
print("Melhor min_child_weight:", best_hyperparams['min_child_weight'])
print("Melhor learning_rate:", best_hyperparams['learning_rate'])
print("Melhor n_estimators:", best_hyperparams['n_estimators'])
print("Melhor max_delta_step:", best_hyperparams['max_delta_step'])
print("Melhor subsample:", best_hyperparams['subsample'])
print("Melhor sampling_method:", best_hyperparams['sampling_method'])
print("Melhor tree_method:", best_hyperparams['tree_method'])
print("Melhor scale_pos_weight:", best_hyperparams['scale_pos_weight'])
# Out:
# Melhor max_depth: 11
# Melhor gamma: 5.880350860717371
# Melhor reg_alpha: 58
# Melhor reg_lambda: 5.463995954893192
# Melhor colsample_bytree: 0.9032830220910373
# Melhor min_child_weight: 13
# Melhor learning_rate: 0.12013987352992113
# Melhor n_estimators: 800
# Melhor max_delta_step: 3.1649267221902466
# Melhor subsample: 0.7740506644342307
# Melhor sampling_method: gradient_based
# Melhor tree_method: hist
# Melhor scale_pos_weight: 11.459234451487069

# %% [markdown]
# # Treinamento do Modelo

# %%
# Preparar os parâmetros do modelo
best_params = {
    'max_depth': int(best_hyperparams['max_depth']),               # Profundidade máxima da árvore
    'n_estimators': int(best_hyperparams['n_estimators']),         # Número de árvores (boost rounds)
    'reg_lambda': best_hyperparams['reg_lambda'],                  # Regularização L2
    'reg_alpha': best_hyperparams['reg_alpha'],                    # Regularização L1
    'gamma': best_hyperparams['gamma'],                            # Redução mínima da perda
    'min_child_weight': int(best_hyperparams['min_child_weight']), # Peso mínimo da folha
    'colsample_bytree': best_hyperparams['colsample_bytree'],      # Amostragem de colunas por árvore
    'learning_rate': best_hyperparams['learning_rate'],            # Taxa de aprendizado
    'max_delta_step': best_hyperparams['max_delta_step'],          # Passo máximo de atualização
    'subsample': best_hyperparams['subsample'],                    # Fração de amostras para cada árvore
    'sampling_method': best_hyperparams['sampling_method'],        # Método de amostragem (e.g., 'uniform' ou 'gradient_based')
    'tree_method': best_hyperparams['tree_method'],                # Método de crescimento da árvore ('hist', 'gpu_hist', etc.)
    'scale_pos_weight': best_hyperparams['scale_pos_weight'],      # Peso para classes desbalanceadas
    'max_cat_to_onehot': best_hyperparams['max_cat_to_onehot'],    # Número máximo de categorias para one-hot
    'max_cat_threshold': best_hyperparams.get('max_cat_threshold', 20), # Limite máximo de categorias (valor padrão incluído)
    'objective': 'binary:logistic',                                # Objetivo do modelo (logística binária)
    'eval_metric': ["aucpr", "auc"],                               # Métrica de avaliação padrão
    'enable_categorical': True,                                    # Suporte a variáveis categóricas
    'validate_parameters': True,                                   # Validação dos parâmetros
    'seed': best_hyperparams.get('seed', 0),                       # Semente para reprodutibilidade
    'random_state': best_hyperparams.get('random_state', 0),       # Estado aleatório
    'device': best_hyperparams.get('device', 'cuda'),              # Especifica o uso de GPU ('cuda' ou 'cpu')
    'verbosity': 1,                                                # Nível de logging do modelo
    'nthread': best_hyperparams.get('nthread', -1)                 # Número de threads para paralelismo
}

# Separar o número de iterações de boosting
num_boost_round = best_params.pop('n_estimators')  # Remove do dict e armazena separadamente

# Treinamento com early stopping
model_class = xgb.train(
    params=best_params,
    dtrain=dtrain_calib,
    num_boost_round=num_boost_round,
    evals=[(dtest, 'validation')],  # Adiciona o conjunto de validação
    early_stopping_rounds=15,      # Critério de parada
    verbose_eval=True              # Mostra o progresso durante o treinamento
)
# Out:
# [0]	validation-aucpr:0.24019	validation-auc:0.64069
# [1]	validation-aucpr:0.26851	validation-auc:0.67114
# [2]	validation-aucpr:0.26457	validation-auc:0.66704
# [3]	validation-aucpr:0.26758	validation-auc:0.66836
# [4]	validation-aucpr:0.27351	validation-auc:0.67366
# [5]	validation-aucpr:0.27321	validation-auc:0.67362
# [6]	validation-aucpr:0.27165	validation-auc:0.67220
# [7]	validation-aucpr:0.27310	validation-auc:0.67365
# [8]	validation-aucpr:0.27131	validation-auc:0.67052
# [9]	validation-aucpr:0.27143	validation-auc:0.67109
# [10]	validation-aucpr:0.27639	validation-auc:0.67562
# [23:14:17] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0750514818a16474a-1\xgboost\xgboost-ci-windows\src\learner.cc:742:
# Parameters: { "enable_categorical" } are not used.
# [11]	validation-aucpr:0.28027	validation-auc:0.67842
# [12]	validation-aucpr:0.28494	validation-auc:0.68153
# [13]	validation-aucpr:0.29099	validation-auc:0.68597
# [14]	validation-aucpr:0.29348	validation-auc:0.68875
# [15]	validation-aucpr:0.29793	validation-auc:0.69147
# [16]	validation-aucpr:0.30027	validation-auc:0.69270
# [17]	validation-aucpr:0.30202	validation-auc:0.69339
# [18]	validation-aucpr:0.30275	validation-auc:0.69453
# [19]	validation-aucpr:0.30523	validation-auc:0.69691
# [20]	validation-aucpr:0.30686	validation-auc:0.69814
# [21]	validation-aucpr:0.31013	validation-auc:0.69997
# [22]	validation-aucpr:0.31127	validation-auc:0.70092
# [23]	validation-aucpr:0.31325	validation-auc:0.70227
# [24]	validation-aucpr:0.31465	validation-auc:0.70328
# [25]	validation-aucpr:0.31603	validation-auc:0.70408
# [26]	validation-aucpr:0.31965	validation-auc:0.70628
# [27]	validation-aucpr:0.32141	validation-auc:0.70731
# [28]	validation-aucpr:0.32201	validation-auc:0.70773
# [29]	validation-aucpr:0.32561	validation-auc:0.70941
# [30]	validation-aucpr:0.32694	validation-auc:0.70999
# [31]	validation-aucpr:0.32867	validation-auc:0.71083
# [32]	validation-aucpr:0.33000	validation-auc:0.71152
# [33]	validation-aucpr:0.33245	validation-auc:0.71266
# [34]	validation-aucpr:0.33380	validation-auc:0.71326
# [35]	validation-aucpr:0.33459	validation-auc:0.71340
# [36]	validation-aucpr:0.33551	validation-auc:0.71390
# [37]	validation-aucpr:0.33677	validation-auc:0.71442
# [38]	validation-aucpr:0.33757	validation-auc:0.71495
# [39]	validation-aucpr:0.33816	validation-auc:0.71508
# [40]	validation-aucpr:0.33861	validation-auc:0.71544
# [41]	validation-aucpr:0.33904	validation-auc:0.71564
# [42]	validation-aucpr:0.33937	validation-auc:0.71598
# [43]	validation-aucpr:0.33976	validation-auc:0.71614
# [44]	validation-aucpr:0.34075	validation-auc:0.71668
# [45]	validation-aucpr:0.34111	validation-auc:0.71691
# [46]	validation-aucpr:0.34165	validation-auc:0.71715
# [47]	validation-aucpr:0.34212	validation-auc:0.71731
# [48]	validation-aucpr:0.34324	validation-auc:0.71780
# [49]	validation-aucpr:0.34341	validation-auc:0.71797
# [50]	validation-aucpr:0.34333	validation-auc:0.71794
# [51]	validation-aucpr:0.34494	validation-auc:0.71878
# [52]	validation-aucpr:0.34517	validation-auc:0.71884
# [53]	validation-aucpr:0.34517	validation-auc:0.71902
# [54]	validation-aucpr:0.34565	validation-auc:0.71923
# [55]	validation-aucpr:0.34640	validation-auc:0.71958
# [56]	validation-aucpr:0.34656	validation-auc:0.71969
# [57]	validation-aucpr:0.34705	validation-auc:0.71991
# [58]	validation-aucpr:0.34781	validation-auc:0.72029
# [59]	validation-aucpr:0.34800	validation-auc:0.72049
# [60]	validation-aucpr:0.34820	validation-auc:0.72062
# [61]	validation-aucpr:0.34841	validation-auc:0.72084
# [62]	validation-aucpr:0.34854	validation-auc:0.72086
# [63]	validation-aucpr:0.34903	validation-auc:0.72108
# [64]	validation-aucpr:0.34967	validation-auc:0.72126
# [65]	validation-aucpr:0.34983	validation-auc:0.72141
# [66]	validation-aucpr:0.34983	validation-auc:0.72149
# [67]	validation-aucpr:0.34981	validation-auc:0.72151
# [68]	validation-aucpr:0.35005	validation-auc:0.72158
# [69]	validation-aucpr:0.34992	validation-auc:0.72156
# [70]	validation-aucpr:0.35023	validation-auc:0.72161
# [71]	validation-aucpr:0.35040	validation-auc:0.72159
# [72]	validation-aucpr:0.35025	validation-auc:0.72158
# [73]	validation-aucpr:0.35055	validation-auc:0.72189
# [74]	validation-aucpr:0.35084	validation-auc:0.72203
# [75]	validation-aucpr:0.35137	validation-auc:0.72228
# [76]	validation-aucpr:0.35194	validation-auc:0.72262
# [77]	validation-aucpr:0.35220	validation-auc:0.72271
# [78]	validation-aucpr:0.35280	validation-auc:0.72312
# [79]	validation-aucpr:0.35294	validation-auc:0.72317
# [80]	validation-aucpr:0.35308	validation-auc:0.72332
# [81]	validation-aucpr:0.35318	validation-auc:0.72343
# [82]	validation-aucpr:0.35308	validation-auc:0.72343
# [83]	validation-aucpr:0.35351	validation-auc:0.72348
# [84]	validation-aucpr:0.35349	validation-auc:0.72348
# [85]	validation-aucpr:0.35349	validation-auc:0.72348
# [86]	validation-aucpr:0.35358	validation-auc:0.72354
# [87]	validation-aucpr:0.35358	validation-auc:0.72354
# [88]	validation-aucpr:0.35368	validation-auc:0.72359
# [89]	validation-aucpr:0.35385	validation-auc:0.72363
# [90]	validation-aucpr:0.35380	validation-auc:0.72358
# [91]	validation-aucpr:0.35381	validation-auc:0.72360
# [92]	validation-aucpr:0.35401	validation-auc:0.72371
# [93]	validation-aucpr:0.35401	validation-auc:0.72371
# [94]	validation-aucpr:0.35401	validation-auc:0.72371
# [95]	validation-aucpr:0.35424	validation-auc:0.72374
# [96]	validation-aucpr:0.35426	validation-auc:0.72374
# [97]	validation-aucpr:0.35429	validation-auc:0.72374
# [98]	validation-aucpr:0.35429	validation-auc:0.72374
# [99]	validation-aucpr:0.35429	validation-auc:0.72374
# [100]	validation-aucpr:0.35431	validation-auc:0.72374
# [101]	validation-aucpr:0.35430	validation-auc:0.72374
# [102]	validation-aucpr:0.35385	validation-auc:0.72365
# [103]	validation-aucpr:0.35387	validation-auc:0.72368
# [104]	validation-aucpr:0.35391	validation-auc:0.72373
# [105]	validation-aucpr:0.35409	validation-auc:0.72386
# [106]	validation-aucpr:0.35409	validation-auc:0.72386
# [107]	validation-aucpr:0.35421	validation-auc:0.72395
# [108]	validation-aucpr:0.35421	validation-auc:0.72395
# [109]	validation-aucpr:0.35378	validation-auc:0.72389
# [110]	validation-aucpr:0.35381	validation-auc:0.72390
# [111]	validation-aucpr:0.35381	validation-auc:0.72390
# [112]	validation-aucpr:0.35381	validation-auc:0.72390
# [113]	validation-aucpr:0.35381	validation-auc:0.72390
# [114]	validation-aucpr:0.35379	validation-auc:0.72394
# [115]	validation-aucpr:0.35431	validation-auc:0.72418
# [116]	validation-aucpr:0.35430	validation-auc:0.72418
# [117]	validation-aucpr:0.35422	validation-auc:0.72417
# [118]	validation-aucpr:0.35422	validation-auc:0.72417
# [119]	validation-aucpr:0.35422	validation-auc:0.72417
# [120]	validation-aucpr:0.35422	validation-auc:0.72417
# [121]	validation-aucpr:0.35422	validation-auc:0.72417
# [122]	validation-aucpr:0.35415	validation-auc:0.72408
# [123]	validation-aucpr:0.35416	validation-auc:0.72408
# [124]	validation-aucpr:0.35416	validation-auc:0.72408
# [125]	validation-aucpr:0.35415	validation-auc:0.72408
# [126]	validation-aucpr:0.35415	validation-auc:0.72408
# [127]	validation-aucpr:0.35452	validation-auc:0.72421
# [128]	validation-aucpr:0.35455	validation-auc:0.72421
# [129]	validation-aucpr:0.35455	validation-auc:0.72421
# [130]	validation-aucpr:0.35455	validation-auc:0.72421
# [131]	validation-aucpr:0.35455	validation-auc:0.72421
# [132]	validation-aucpr:0.35482	validation-auc:0.72432
# [133]	validation-aucpr:0.35482	validation-auc:0.72432
# [134]	validation-aucpr:0.35485	validation-auc:0.72442
# [135]	validation-aucpr:0.35502	validation-auc:0.72448
# [136]	validation-aucpr:0.35502	validation-auc:0.72448
# [137]	validation-aucpr:0.35502	validation-auc:0.72448
# [138]	validation-aucpr:0.35502	validation-auc:0.72448
# [139]	validation-aucpr:0.35502	validation-auc:0.72448
# [140]	validation-aucpr:0.35502	validation-auc:0.72448
# [141]	validation-aucpr:0.35502	validation-auc:0.72448
# [142]	validation-aucpr:0.35501	validation-auc:0.72447
# [143]	validation-aucpr:0.35501	validation-auc:0.72447
# [144]	validation-aucpr:0.35501	validation-auc:0.72447
# [145]	validation-aucpr:0.35501	validation-auc:0.72447
# [146]	validation-aucpr:0.35503	validation-auc:0.72448
# [147]	validation-aucpr:0.35503	validation-auc:0.72448
# [148]	validation-aucpr:0.35503	validation-auc:0.72448
# [149]	validation-aucpr:0.35502	validation-auc:0.72447
# [150]	validation-aucpr:0.35502	validation-auc:0.72447
# [151]	validation-aucpr:0.35512	validation-auc:0.72452
# [152]	validation-aucpr:0.35512	validation-auc:0.72452
# [153]	validation-aucpr:0.35512	validation-auc:0.72452
# [154]	validation-aucpr:0.35506	validation-auc:0.72444
# [155]	validation-aucpr:0.35507	validation-auc:0.72444
# [156]	validation-aucpr:0.35529	validation-auc:0.72449
# [157]	validation-aucpr:0.35536	validation-auc:0.72448
# [158]	validation-aucpr:0.35536	validation-auc:0.72448
# [159]	validation-aucpr:0.35540	validation-auc:0.72446
# [160]	validation-aucpr:0.35540	validation-auc:0.72446
# [161]	validation-aucpr:0.35531	validation-auc:0.72447
# [162]	validation-aucpr:0.35531	validation-auc:0.72447
# [163]	validation-aucpr:0.35532	validation-auc:0.72447
# [164]	validation-aucpr:0.35532	validation-auc:0.72447
# [165]	validation-aucpr:0.35532	validation-auc:0.72447
# [166]	validation-aucpr:0.35532	validation-auc:0.72447

# %% [markdown]
# ## Analise do Resultado

# %% [markdown]
# Métricas: <br>
#
# AUC: 0.67 <br>
# O modelo tem uma capacidade razoável de distinguir entre as classes, mas ainda há espaço para melhoria. Geralmente valores AUX acima de 0.7 são os mais desejáveis nos modelos de classificação.
#
# A Área Sob a Curva (AUC) da curva ROC é um indicador do poder discriminatório do modelo, ou seja, sua capacidade de distinguir entre as classes positivas e negativas. Um AUC de 0.67 indica um desempenho moderado. Em uma escala de 0 a 1, onde 0,5 seria uma classificação aleatória e 1 uma classificação perfeita, 0.67 é superior ao aleatório. Geralmente valores AUX acima de 0.7 são os mais desejáveis nos modelos de classificação.<br>
#
# Acurácia: 80.4%  <br>
# A acurácia é a proporção de previsões corretas (tanto verdadeiros positivos quanto verdadeiros negativos) em relação ao total de previsões. Uma acurácia de 80.4% é relativamente alta, o que sugere que o modelo é geralmente preciso nas suas previsões. No entanto, a acurácia pode ser enganosa em conjuntos de dados desbalanceados. Que é o nosso contexto, portanto temos que tomar cuidado com ela. <br>
#
# Precisão: 88.73%<br>
# A precisão mede a proporção de verdadeiros positivos em relação ao total de positivos previstos pelo modelo. Uma precisão de quase 89% indica que, quando o modelo prevê a classe positiva, é correto na maioria das vezes. Vale lembrar que a classe positiva é o voo ter sido realizado de forma pontual. <br>
#
# Recall: 88.20%<br>
# O recall mede a proporção de verdadeiros positivos em relação ao total de casos positivos reais. Um recall de cerca de 88% indica que o modelo é capaz de identificar a maioria dos casos positivos reais.<br>
#
# F1-score: 88.47%<br>
# O F1-score é a média harmônica da precisão e do recall. Um valor próximo a 89% é considerado alto e indica um bom equilíbrio entre precisão e recall, o que é desejável em cenários de classificação.<br>
#
# No nosso contexto, onde a base de dados está desbalanceada as metricas ROC e AUC se torna uma métrica valiosa para entender a performance do modelo.

# %%
#file_path_x = 'df_xtest_hold.csv'
#X_test = pd.read_csv(file_path_x)

#file_path_y = 'df_ytest_hold.csv'
#y_test = pd.read_csv(file_path_y)

# %%
import numpy as np
from sklearn.metrics import (
    accuracy_score, confusion_matrix, precision_score, recall_score,
    f1_score, roc_auc_score, balanced_accuracy_score, average_precision_score,
    log_loss, brier_score_loss, cohen_kappa_score, matthews_corrcoef
)

# Garantir que y_test e y_pred_proba sejam arrays NumPy
y_test_np = np.array(y_test)  # Converte y_test para NumPy se necessário
y_pred_proba = model_class.predict(dtest)  # Previsões no formato de probabilidades da classe positiva

# Prever as classes com base no limiar de 0.5
y_pred = (y_pred_proba >= 0.5).astype(int)

# Matriz de confusão e cálculos básicos
cm = confusion_matrix(y_test_np, y_pred)
TN, FP, FN, TP = cm.ravel()
accuracy = accuracy_score(y_test_np, y_pred)
sensitivity = TP / (TP + FN) if (TP + FN) > 0 else 0
specificity = TN / (TN + FP) if (TN + FP) > 0 else 0
precision = TP / (TP + FP) if (TP + FP) > 0 else 0
recall = sensitivity
f1 = (2 * precision * recall) / (precision + recall) if (precision + recall) > 0 else 0
balanced_acc = balanced_accuracy_score(y_test_np, y_pred)
fpr = FP / (FP + TN) if (FP + TN) > 0 else 0
fnr = FN / (FN + TP) if (FN + TP) > 0 else 0

# Métricas baseadas em probabilidades
prauc = average_precision_score(y_test_np, y_pred_proba)
auc = roc_auc_score(y_test_np, y_pred_proba)
gini = 2 * auc - 1
mcc = matthews_corrcoef(y_test_np, y_pred)
log_loss_value = log_loss(y_test_np, y_pred_proba)
brier_score = brier_score_loss(y_test_np, y_pred_proba)
kappa = cohen_kappa_score(y_test_np, y_pred)

# Geometric Mean (G-Mean)
g_mean = np.sqrt(sensitivity * specificity)

# Exibir as métricas
print(f'Accuracy: {accuracy:.3f}')
print(f'Precision: {precision:.3f}')
print(f'Recall: {recall:.3f}')
print(f'F1-Score: {f1:.3f}')
print(f'PRAUC: {prauc:.3f}')
print(f'AUC: {auc:.3f}')
print(f'Gini Coefficient: {gini:.3f}')
print(f'MCC: {mcc:.3f}')
print(f'Log Loss: {log_loss_value:.3f}')
print(f'Brier Score: {brier_score:.3f}')
print(f'Cohen\'s Kappa: {kappa:.3f}')
print(f'Balanced Accuracy: {balanced_acc:.3f}')
print(f'Specificity: {specificity:.3f}')
print(f'False Positive Rate (FPR): {fpr:.3f}')
print(f'False Negative Rate (FNR): {fnr:.3f}')
print(f'Geometric Mean (G-Mean): {g_mean:.3f}')
# Out:
# Accuracy: 0.178
# Precision: 0.172
# Recall: 0.999
# F1-Score: 0.293
# PRAUC: 0.355
# AUC: 0.724
# Gini Coefficient: 0.449
# MCC: 0.033
# Log Loss: 1.731
# Brier Score: 0.605
# Cohen's Kappa: 0.003
# Balanced Accuracy: 0.504
# Specificity: 0.009
# False Positive Rate (FPR): 0.991
# False Negative Rate (FNR): 0.001
# Geometric Mean (G-Mean): 0.094

# %% [markdown]
# ### Feature Importance

# %%
plt.rcParams['figure.figsize'] = [13, 9]
xgb.plot_importance(model_class, max_num_features=20)
plt.show()

# %% [markdown]
# #### Treeplot

# %%
# plot single tree
#fig, ax = plt.subplots(figsize=(100, 100))
#fig = plt.figure(figsize=(12, 6))
plt.figure(figsize=(50, 50))
plot_tree(model_class)
#plt.savefig('xgb_treeplot.jpg', dpi=1800)  
plt.show()
# Out:
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.180251 to fit

# %% [markdown]
# ### Matriz de Confusão

# %% [markdown]
# O gráfico de calor mostra as previsões do modelo em relação aos valores reais. Os valores na diagonal (7979 e 148171) representam as previsões corretas para as classes negativas (0) e positivas (1), respectivamente. Os outros dois valores (19805 e 18812) representam os erros do tipo I(falsos negativos) e tipo II(falsos positivos), respectivamente. A matriz sugere que o modelo é melhor em prever a classe majoritária (Pontual) do que a minoritária (Atraso), o que é comum em conjuntos de dados desbalanceados.

# %%
# Matriz de Confusão
cm = confusion_matrix(y_test, y_pred)
sns.heatmap(cm, annot=True, fmt='d')
plt.title('Matriz de Confusão')
plt.show()

# %% [markdown]
# ### Curva ROC

# %% [markdown]
# A relação entre a taxa de verdadeiro positivo e a taxa de falso positivo para diferentes limiares de classificação. A curva está suave e sobe gradualmente. No entanto, uma curva ROC ideal se aproximaria mais do canto superior esquerdo mais rápido. A consequência é que temos uma alta taxa de verdadeiro positivo e baixa taxa de falso positivo. Isso devido ao banco de dados desbalanceado. O resultado nos permit dizer que ainda há um potencial de melhoria no modelo

# %%
# Gerar previsões probabilísticas para a classe positiva
y_pred_proba_pos = model_class.predict(dtest)   # Probabilidades da classe positiva

fpr, tpr, thresholds = roc_curve(y_test, y_pred_proba_pos)

# Plot da Curva ROC
plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, label=f'Modelo AUC: {roc_auc_score(y_test_np, y_pred_proba):.3f})')
plt.title('Curva ROC', fontsize=14)
plt.xlabel('Taxa de Falso Positivo (FPR)', fontsize=12)
plt.ylabel('Taxa de Verdadeiro Positivo (TPR)', fontsize=12)
plt.grid(True)
plt.legend()
plt.show()

# %% [markdown]
# ### Curva de Precisão-Recall

# %% [markdown]
# Este gráfico é útil em situações de classes desbalanceadas e foca na relação entre precisão (quão muitos dos classificados como positivos são realmente positivos) e recall (quão muitos dos positivos reais foram capturados pelo modelo). A curva começa com uma alta precisão, mas diminui à medida que o recall aumenta, isso pode ser um sinal de que pode estar acontecendo um trade-off, ou seja, visando ter mais ou manter performance.

# %%
from sklearn.metrics import precision_recall_curve
import matplotlib.pyplot as plt

# Gerar previsões probabilísticas para a classe positiva
y_pred_proba_pos = model_class.predict(dtest)   # Probabilidades da classe positiva

# Curva de Precisão-Recall
precision, recall, _ = precision_recall_curve(y_test, y_pred_proba_pos)

# Plot da Curva de Precisão-Recall
plt.figure(figsize=(8, 6))
plt.plot(recall, precision, label='Modelo XGBoost')
plt.title('Curva de Precisão-Recall', fontsize=14)
plt.xlabel('Recall', fontsize=12)
plt.ylabel('Precisão', fontsize=12)
plt.grid(True)
plt.legend()
plt.show()

# %% [markdown]
# ### Calibration plot

# %%
from sklearn.calibration import calibration_curve
import matplotlib.pyplot as plt

# Prever probabilidades da classe positiva no conjunto de teste
y_pred_proba = model_class.predict(dtest_calib)  # Probabilidades da classe positiva


# Obter os valores para o gráfico de calibração antes e depois da calibração
prob_true_uncalibrated, prob_pred_uncalibrated = calibration_curve(y_test, y_pred_test_uncalibrated, n_bins=15, strategy='uniform')

# Plotar o gráfico
plt.figure(figsize=(10, 6))
plt.plot(prob_pred_uncalibrated, prob_true_uncalibrated, marker='o', label='Sem Calibração')
plt.plot([0, 1], [0, 1], linestyle='--', label='Perfeitamente Calibrado')
plt.xlabel('Probabilidade prevista')
plt.ylabel('Proporção observada')
plt.title('Gráfico de Calibração')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# # Implementando Calibração

# %%
from xgboost import XGBClassifier
from sklearn.calibration import CalibratedClassifierCV
from sklearn.metrics import log_loss, roc_auc_score, brier_score_loss, make_scorer
from sklearn.model_selection import RepeatedStratifiedKFold, cross_val_score
import numpy as np

# Funções para métricas adicionais
def calculate_overconfidence_error(y_true, y_pred, bins=10):
    """Calcula o erro de overconfidence."""
    bin_edges = np.linspace(0, 1, bins + 1)
    bin_sums = np.zeros(bins)
    bin_counts = np.zeros(bins)

    for i in range(bins):
        bin_mask = (y_pred >= bin_edges[i]) & (y_pred < bin_edges[i + 1])
        bin_sums[i] = np.sum(y_pred[bin_mask]) - np.sum(y_true[bin_mask])
        bin_counts[i] = np.sum(bin_mask)

    overconfidence_error = np.sum(np.abs(bin_sums) / bin_counts) / bins
    return overconfidence_error

def calculate_ece_mce(y_true, y_pred, bins=10):
    """Calcula o Expected Calibration Error (ECE) e Maximum Calibration Error (MCE)."""
    bin_edges = np.linspace(0, 1, bins + 1)
    ece = 0
    mce = 0

    for i in range(bins):
        bin_mask = (y_pred >= bin_edges[i]) & (y_pred < bin_edges[i + 1])
        bin_true = y_true[bin_mask]
        bin_pred = y_pred[bin_mask]

        if len(bin_true) > 0:
            accuracy = np.mean(bin_true)
            avg_confidence = np.mean(bin_pred)
            bin_error = np.abs(accuracy - avg_confidence)

            ece += bin_error * len(bin_true)
            mce = max(mce, bin_error)

    ece /= len(y_true)
    return ece, mce

def evaluate_metrics(y_true, y_pred, title="Metrics"):
    """Calcula e exibe as métricas."""
    logloss = log_loss(y_true, y_pred)
    auc = roc_auc_score(y_true, y_pred)
    brier = brier_score_loss(y_true, y_pred)
    overconfidence = calculate_overconfidence_error(y_true, y_pred)
    ece, mce = calculate_ece_mce(y_true, y_pred)

    print(f"--- {title} ---")
    print(f"Log Loss: {logloss:.4f}")
    print(f"AUC: {auc:.4f}")
    print(f"Brier Score: {brier:.4f}")
    print(f"Overconfidence Error: {overconfidence:.4f}")
    print(f"Expected Calibration Error (ECE): {ece:.4f}")
    print(f"Maximum Calibration Error (MCE): {mce:.4f}")

# Ajustar os parâmetros para XGBClassifier
classifier_params = best_params.copy()
classifier_params['n_estimators'] = num_boost_round  # Número de iterações de boosting

# Configuração do modelo XGBClassifier
model = XGBClassifier(**classifier_params)

# Treinamento do modelo inicial sem calibração
model.fit(X_train_calib, y_train_calib)
y_pred_test_uncalibrated = model.predict_proba(X_test)[:, 1]

# Avaliar métricas antes da calibração
print("\nBefore Calibration")
evaluate_metrics(y_test, y_pred_test_uncalibrated, title="Uncalibrated")

# Validação cruzada na calibração com RepeatedStratifiedKFold
cv = RepeatedStratifiedKFold(n_splits=7, n_repeats=5, random_state=42)

# Calibração isotônica com validação cruzada
calibrated = CalibratedClassifierCV(model, method='isotonic', cv=cv)

# Avaliar o modelo calibrado com cross-validation
roc_auc_scorer = make_scorer(roc_auc_score, needs_proba=True)
scores = cross_val_score(calibrated, X_test_calib, y_test_calib, scoring=roc_auc_scorer, cv=cv, n_jobs=-1)

# Exibir resultados de validação cruzada
print(f"Mean ROC AUC (cross-validation): {np.mean(scores):.4f}")
print(f"Standard Deviation ROC AUC (cross-validation): {np.std(scores):.4f}")

# Ajustar o modelo calibrado para avaliação no conjunto de teste
calibrated.fit(X_test_calib, y_test_calib)

# Predições no conjunto de teste após calibração
y_pred_test_calibrated = calibrated.predict_proba(X_test)[:, 1]

# Avaliar métricas após calibração no conjunto de teste
print("\nAfter Calibration")
evaluate_metrics(y_test, y_pred_test_calibrated, title="Calibrated")
# Out:
# [23:14:23] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0750514818a16474a-1\xgboost\xgboost-ci-windows\src\common\error_msg.cc:58: Falling back to prediction using DMatrix due to mismatched devices. This might lead to higher memory usage and slower performance. XGBoost is running on: cuda:0, while the input data is on: cpu.
# Potential solutions:
# - Use a data structure that matches the device ordinal in the booster.
# - Set the device for booster before call to inplace_predict.
#
# This warning will only be shown once.
#
# The `needs_threshold` and `needs_proba` parameter are deprecated in version 1.4 and will be removed in 1.6. You can either let `response_method` be `None` or set it to `predict` to preserve the same behaviour.
# Before Calibration
# --- Uncalibrated ---
# Log Loss: 0.8068
# AUC: 0.7290
# Brier Score: 0.2957
# Overconfidence Error: 0.3265
# Expected Calibration Error (ECE): 0.3998
# Maximum Calibration Error (MCE): 0.5014
# Mean ROC AUC (cross-validation): 0.7274
# Standard Deviation ROC AUC (cross-validation): 0.0064
#
# After Calibration
# --- Calibrated ---
# Log Loss: 0.4122
# AUC: 0.7230
# Brier Score: 0.1281
# Overconfidence Error: nan
# Expected Calibration Error (ECE): 0.0185
# Maximum Calibration Error (MCE): 0.1602
# invalid value encountered in divide

# %%
from sklearn.calibration import calibration_curve
import matplotlib.pyplot as plt

# Prever probabilidades da classe positiva no conjunto de teste
y_pred_proba = model_class.predict(dtest_calib)  # Probabilidades da classe positiva


# Obter os valores para o gráfico de calibração antes e depois da calibração
prob_true_uncalibrated, prob_pred_uncalibrated = calibration_curve(y_test, y_pred_test_uncalibrated, n_bins=15, strategy='uniform')
prob_true_calibrated, prob_pred_calibrated = calibration_curve(y_test, y_pred_test_calibrated, n_bins=15, strategy='uniform')

# Plotar o gráfico
plt.figure(figsize=(10, 6))
plt.plot(prob_pred_uncalibrated, prob_true_uncalibrated, marker='o', label='Antes da Calibração')
plt.plot(prob_pred_calibrated, prob_true_calibrated, marker='o', label='Após Regressão Isotônica', color='blue')
plt.plot([0, 1], [0, 1], linestyle='--', label='Perfeitamente Calibrado')
plt.xlabel('Probabilidade prevista')
plt.ylabel('Proporção observada')
plt.title('Gráfico de Calibração')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ## Análise após calibração do modelo

# %%
from sklearn.metrics import (
    accuracy_score, confusion_matrix, precision_score, recall_score,
    f1_score, roc_auc_score, balanced_accuracy_score, average_precision_score,
    log_loss, brier_score_loss, cohen_kappa_score, matthews_corrcoef,
    roc_curve, precision_recall_curve
)
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# Garantir que y_test e y_pred_proba sejam arrays NumPy
y_test_np = np.array(y_test)  # Converte y_test para NumPy se necessário

# Gerar previsões probabilísticas para a classe positiva após calibração
y_pred_proba = calibrated.predict_proba(X_test)[:, 1]  # Previsões calibradas (probabilidades)

# Prever as classes com base no limiar de 0.5
y_pred = (y_pred_proba >= 0.5).astype(int)

# Matriz de Confusão
cm = confusion_matrix(y_test_np, y_pred)
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.title('Matriz de Confusão')
plt.xlabel('Predito')
plt.ylabel('Real')
plt.show()

# Curva ROC
fpr, tpr, thresholds = roc_curve(y_test_np, y_pred_proba)
plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, label=f'Modelo Calibrado (AUC: {roc_auc_score(y_test_np, y_pred_proba):.3f})')
plt.title('Curva ROC', fontsize=14)
plt.xlabel('Taxa de Falso Positivo (FPR)', fontsize=12)
plt.ylabel('Taxa de Verdadeiro Positivo (TPR)', fontsize=12)
plt.grid(True)
plt.legend()
plt.show()

# Curva de Precisão-Recall
precision, recall, _ = precision_recall_curve(y_test_np, y_pred_proba)
plt.figure(figsize=(8, 6))
plt.plot(recall, precision, label=f'Modelo Calibrado (PRAUC: {average_precision_score(y_test_np, y_pred_proba):.3f})')
plt.title('Curva de Precisão-Recall', fontsize=14)
plt.xlabel('Recall', fontsize=12)
plt.ylabel('Precisão', fontsize=12)
plt.grid(True)
plt.legend()
plt.show()

# Cálculos de Métricas
TN, FP, FN, TP = cm.ravel()
accuracy = accuracy_score(y_test_np, y_pred)
sensitivity = TP / (TP + FN) if (TP + FN) > 0 else 0
specificity = TN / (TN + FP) if (TN + FP) > 0 else 0
precision = TP / (TP + FP) if (TP + FP) > 0 else 0
recall = sensitivity
f1 = (2 * precision * recall) / (precision + recall) if (precision + recall) > 0 else 0
balanced_acc = balanced_accuracy_score(y_test_np, y_pred)
fpr = FP / (FP + TN) if (FP + TN) > 0 else 0
fnr = FN / (FN + TP) if (FN + TP) > 0 else 0

# Métricas baseadas em probabilidades
prauc = average_precision_score(y_test_np, y_pred_proba)
auc = roc_auc_score(y_test_np, y_pred_proba)
gini = 2 * auc - 1
mcc = matthews_corrcoef(y_test_np, y_pred)
log_loss_value = log_loss(y_test_np, y_pred_proba)
brier_score = brier_score_loss(y_test_np, y_pred_proba)
kappa = cohen_kappa_score(y_test_np, y_pred)

# Geometric Mean (G-Mean)
g_mean = np.sqrt(sensitivity * specificity)

# Exibir as métricas
print(f'Accuracy: {accuracy:.3f}')
print(f'Precision: {precision:.3f}')
print(f'Recall: {recall:.3f}')
print(f'F1-Score: {f1:.3f}')
print(f'PRAUC: {prauc:.3f}')
print(f'AUC: {auc:.3f}')
print(f'Gini Coefficient: {gini:.3f}')
print(f'MCC: {mcc:.3f}')
print(f'Log Loss: {log_loss_value:.3f}')
print(f'Brier Score: {brier_score:.3f}')
print(f'Cohen\'s Kappa: {kappa:.3f}')
print(f'Balanced Accuracy: {balanced_acc:.3f}')
print(f'Specificity: {specificity:.3f}')
print(f'False Positive Rate (FPR): {fpr:.3f}')
print(f'False Negative Rate (FNR): {fnr:.3f}')
print(f'Geometric Mean (G-Mean): {g_mean:.3f}')
# Out:
# Accuracy: 0.831
# Precision: 0.626
# Recall: 0.029
# F1-Score: 0.056
# PRAUC: 0.360
# AUC: 0.723
# Gini Coefficient: 0.446
# MCC: 0.108
# Log Loss: 0.412
# Brier Score: 0.128
# Cohen's Kappa: 0.041
# Balanced Accuracy: 0.513
# Specificity: 0.996
# False Positive Rate (FPR): 0.004
# False Negative Rate (FNR): 0.971
# Geometric Mean (G-Mean): 0.171

# %% [markdown]
# ### Shap
# (análise do modelo e não do modelo calibrado)

# %% [markdown]
# O Shap nos permite compreender o peso de cada variavel para o modelo

# %%
explainer = shap.Explainer(model)
shap_values = explainer(X_test)
shap_importance = shap_values.abs.mean(0).values
sorted_idx = shap_importance.argsort()
shap.plots.bar(shap_values, max_display=18)
# Out:
# [22:49:42] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0750514818a16474a-1\xgboost\xgboost-ci-windows\src\c_api\c_api.cc:1240: Saving into deprecated binary model format, please consider using `json` or `ubj`. Model format will default to JSON in XGBoost 2.2 if not specified.

# %%
pred = model.predict(X_test_calib, output_margin=True)

explainer = shap.TreeExplainer(model)
explanation = explainer(dtest_calib)

shap_values = explanation.values

shap.plots.beeswarm(explanation)

# make sure the SHAP values add up to marginal predictions
np.abs(shap_values.sum(axis=1) + explanation.base_values - y_test_calib).max()

#dtest_calib.feature_names
# Out:
# [22:38:19] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0750514818a16474a-1\xgboost\xgboost-ci-windows\src\c_api\c_api.cc:1240: Saving into deprecated binary model format, please consider using `json` or `ubj`. Model format will default to JSON in XGBoost 2.2 if not specified.
# ['nome_empresas',
#  'descricao_origem',
#  'descricao_destino',
#  'cidade_origem',
#  'uf_origem',
#  'cidade_destino',
#  'uf_destino',
#  'mes_partida',
#  'dia_semana_partida',
#  'dia_mes_partida',
#  'hora_partida',
#  'latitude_aero_origem',
#  'longitude_aero_origem',
#  'latitude_aero_destino',
#  'longitude_aero_destino',
#  'rota',
#  'regiao_origem',
#  'precipitacao_total_horario_mm__origem',
#  'regiao_destino',
#  'vento_direcao_horaria_gr_deg_gr__destino',
#  'numero_empresa_voo',
#  'pca_pressao_origem_pca1',
#  'pca_umidade_origem_pca1',
#  'pca_pressao_destino_pca1',
#  'pca_umidade_destino_pca1',
#  'pca_temperatura_origem_pca1',
#  'pca_temperatura_destino_pca1',
#  'pca_vento_origem_pca1',
#  'pca_vento_destino_pca1']

# %%
pred = model.predict(X_test_calib, output_margin=True)

explainer = shap.TreeExplainer(model)
explanation = explainer(X_test)

shap_values = explanation.values

shap.plots.beeswarm(explanation)

# make sure the SHAP values add up to marginal predictions
np.abs(shap_values.sum(axis=1) + explanation.base_values - y_test).max()
# Out:
# [22:37:19] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0750514818a16474a-1\xgboost\xgboost-ci-windows\src\c_api\c_api.cc:1240: Saving into deprecated binary model format, please consider using `json` or `ubj`. Model format will default to JSON in XGBoost 2.2 if not specified.
# 4.0122833251953125

# %%
X_test
dtest

# %% [markdown]
# # Salvando o Modelo

# %%
# Salvar o modelo
save_pickle(model_class, 'modelo/modelo_xgboost_50_50.pkl')

# %%
calibrated
# Out:
# CalibratedClassifierCV(cv=RepeatedStratifiedKFold(n_repeats=5, n_splits=7, random_state=42),
#                        estimator=XGBClassifier(base_score=None, booster=None,
#                                                callbacks=None,
#                                                colsample_bylevel=None,
#                                                colsample_bynode=None,
#                                                colsample_bytree=0.9032830220910373,
#                                                device='cuda',
#                                                early_stopping_rounds=None,
#                                                enable_categorical=True,
#                                                eval_metric=['aucpr', 'auc'],
#                                                feature_types=None...
#                                                importance_type=None,
#                                                interaction_constraints=None,
#                                                learning_rate=0.12013987352992113,
#                                                max_bin=None,
#                                                max_cat_threshold=13,
#                                                max_cat_to_onehot=23,
#                                                max_delta_step=3.1649267221902466,
#                                                max_depth=11, max_leaves=None,
#                                                min_child_weight=13, missing=nan,
#                                                monotone_constraints=None,
#                                                multi_strategy=None,
#                                                n_estimators=800, n_jobs=None,
#                                                nthread=-1,
#                                                num_parallel_tree=None, ...),
#                        method='isotonic')

# %%
# Salvar o modelo
save_pickle(calibrated, 'modelo/modelo_xgboost_calibrated_50_50.pkl')

# %% [markdown]
# # Load no modelo

# %%
# Carregar o modelo
modelo_carregado = load_pickle('modelo/modelo_pkl/modelo_classificao_v3.pkl')

# %% [markdown]
# # Conclusões

# %% [markdown]
# Ao considerar todas essas métricas e gráficos em conjunto, podemos concluir que o modelo tem um desempenho mediano para bom, com uma boa precisão e recall. No entanto, a AUC indica que ainda há espaço para melhoria na capacidade do modelo de diferenciar entre as classes. Além disso, o modelo parece ser confiável em sua capacidade de identificar a classe positiva (alta precisão), e é capaz de capturar a maioria dos positivos reais (alto recall).<br>
#
# Apesar dos resultados o modelo ainda carece de outras informações que poderiam ajudar a predizer melhor se o voo vai atrasar ou não, por exemplo:<br>
#
# - Dados da meteorologia  o aeroporto de partida e de chegada<br>
# - Quantidade de pessoas que estão abordas no voo<br>
# - Informações da aeronova (quantidade de dias desde de sua última manutenção, modelo da aeronave)<br>
# - Quantidade de pousos e decolagens previstos para o aeroporto naquele dia<br>
# - Distância do voo<br>
# - Tempo de voo do piloto<br>
#
# Tais dimensões ajudariam a metrificar outros elementos que são capazes de interferir diretamente no atraso ou não do voo. <br>

# %% [markdown]
# # Catboost

# %%
# Seleção das features (variáveis) preditoras e a variável alvo
dt_ax = df.drop(columns=["status_do_voo"])
dt_ay = df['status_do_voo'].map({'Pontual': 0, 'Atrasado': 1})

# Dividir os dados em treino e teste
X_train, X_test, y_train, y_test = train_test_split(dt_ax, dt_ay, test_size=0.25, random_state=42)

# %%
def hipertuning(space):
    """
    Realiza o ajuste de hiperparâmetros de um modelo CatBoost usando validação cruzada.

    Args:
    space (dict): Dicionário contendo os hiperparâmetros para teste no modelo CatBoost.

    Returns:
    dict: Dicionário contendo o 'loss' (negativo da média da AUC) e o 'status'.
    """
    # Identificar características categóricas
    cat_features = X_train.select_dtypes(include=['object', 'category']).columns.tolist()
    cat_feature_indices = [X_train.columns.get_loc(col) for col in cat_features]

    # Configuração do modelo com os parâmetros do espaço
    clf = ctb.CatBoostClassifier(
        iterations=int(space['iterations']),
        depth=int(space['depth']),
        learning_rate=space['learning_rate'],
        l2_leaf_reg=space['l2_leaf_reg'],
        border_count=int(space['border_count']),
        random_seed=int(space['random_seed']),
        eval_metric='AUC',
        logging_level='Silent',
        class_weights=space['class_weights']
    )

    # StratifiedKFold para manter a proporção de classes em cada fold
    skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

    # Avaliação usando cross_validate
    auc_scores = cross_validate(
        clf,
        X_train,
        y_train,
        cv=skf,
        scoring='roc_auc',
        fit_params={'cat_features': cat_feature_indices}
    )

    mean_auc = auc_scores['test_score'].mean()
    print("Média AUC: ", mean_auc)

    # A função de perda é o negativo da média do AUC
    return {'loss': -mean_auc, 'status': STATUS_OK}

# %%
# Executando o tuning de hiperparâmetros com Hyperopt
trials = Trials()
best = fmin(
    fn=hipertuning,
    space=space,
    algo=tpe.suggest,
    max_evals=7,
    trials=trials)

print("Melhores hiperparâmetros encontrados:")
print(best)

# %%
best['class_weights']

# %%
# Configuração dos hiperparâmetros com os melhores valores encontrados
best_hyperparams = {
    'iterations': [100, 200, 300][best['iterations']],  # Seleciona o número de iterações da lista original
    'depth': int(best['depth']),
    'learning_rate': best['learning_rate'],
    'l2_leaf_reg': best['l2_leaf_reg'],
    'class_weights': [{0: 1, 1: 2}, {0: 1, 1: 3}, {0: 1, 1: 5}][best['class_weights']]
}

# Identificar as colunas categóricas
cat_features = X_train.select_dtypes(include=['object', 'category']).columns.tolist()
cat_feature_indices = [X_train.columns.get_loc(col) for col in cat_features]

# Definir o modelo CatBoost com os melhores hiperparâmetros
model_class = CatBoostClassifier(
    iterations=best_hyperparams['iterations'],
    depth=best_hyperparams['depth'],
    learning_rate=best_hyperparams['learning_rate'],
    l2_leaf_reg=best_hyperparams['l2_leaf_reg'],
    eval_metric='AUC',
    logging_level='Silent',
    class_weights=best_hyperparams['class_weights']
)

# Treinamento do modelo com os dados balanceados
model_class.fit(X_train, y_train, cat_features=cat_feature_indices)

# %%
from imblearn.over_sampling import SMOTENC
from sklearn.model_selection import StratifiedKFold, train_test_split, cross_validate
import catboost as ctb
from hyperopt import hp, fmin, tpe, Trials, STATUS_OK
import numpy as np
import pandas as pd

# Seleção das features (variáveis) preditoras e a variável alvo
dt_ax = df.drop(columns=["status_do_voo"])
dt_ay = df['status_do_voo'].map({'Pontual': 0, 'Atrasado': 1})

# Dividir os dados em treino e teste
X_train, X_test, y_train, y_test = train_test_split(dt_ax, dt_ay, test_size=0.25, random_state=42)

# %%
X_train

# %%
# Seleção das features (variáveis) preditoras e a variável alvo
dt_ax = df.drop(columns=["status_do_voo"])
dt_ay = df['status_do_voo'].map({'Pontual': 0, 'Atrasado': 1})

# Dividir os dados em treino e teste
X_train, X_test, y_train, y_test = train_test_split(dt_ax, dt_ay, test_size=0.25, random_state=42)

# Função para realizar o ajuste de hiperparâmetros com CatBoost
def hipertuning(space):
    """
    Realiza o ajuste de hiperparâmetros de um modelo CatBoost usando validação cruzada.

    Args:
    space (dict): Dicionário contendo os hiperparâmetros para teste no modelo CatBoost.

    Returns:
    dict: Dicionário contendo o 'loss' (negativo da média da AUC) e o 'status'.
    """
    # Identificar características categóricas
    cat_features = X_train.select_dtypes(include=['object', 'category']).columns.tolist()
    cat_feature_indices = [X_train.columns.get_loc(col) for col in cat_features]

    # Configurar o OneHotEncoder com sparse_output=False
    ohe = OneHotEncoder(sparse_output=False, handle_unknown="ignore")

    # Aplicação do SMOTENC para dados de treino balanceados
    smotenc = SMOTENC(categorical_features=cat_feature_indices, categorical_encoder=ohe, random_state=42, sampling_strategy='not majority')
    X_resampled, y_resampled = smotenc.fit_resample(X_train, y_train)

    # Configuração do modelo com os hiperparâmetros do espaço
    clf = ctb.CatBoostClassifier(
        iterations=int(space['iterations']),
        depth=int(space['depth']),
        learning_rate=space['learning_rate'],
        l2_leaf_reg=space['l2_leaf_reg'],
        border_count=int(space['border_count']),
        random_seed=int(space['random_seed']),
        eval_metric='AUC',
        logging_level='Silent',
        class_weights=space['class_weights']
    )

    # StratifiedKFold para manter a proporção de classes em cada fold
    skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

    # Avaliação usando cross_validate
    auc_scores = cross_validate(
        clf,
        X_resampled,
        y_resampled,
        cv=skf,
        scoring='roc_auc',
        fit_params={'cat_features': cat_feature_indices}
    )

    mean_auc = auc_scores['test_score'].mean()
    print("Média AUC: ", mean_auc)

    # A função de perda é o negativo da média do AUC
    return {'loss': -mean_auc, 'status': STATUS_OK}

# Espaço de busca para hiperparâmetros
space = {
    'iterations': hp.choice('iterations', [100, 200, 300]),
    'depth': hp.quniform('depth', 3, 10, 1),
    'learning_rate': hp.uniform('learning_rate', 0.01, 0.3),
    'l2_leaf_reg': hp.uniform('l2_leaf_reg', 1, 10),
    'border_count': hp.quniform('border_count', 32, 255, 1),
    'random_seed': 42,
    'class_weights': hp.choice('class_weights', [
        None,
        {0: 1, 1: 2},
        {0: 1, 1: 3},
        {0: 1, 1: 5}
    ])
}

# Executando o tuning de hiperparâmetros com Hyperopt
trials = Trials()
best = fmin(
    fn=hipertuning,
    space=space,
    algo=tpe.suggest,
    max_evals=1,
    trials=trials
)

print("Melhores hiperparâmetros encontrados:")
print(best)

# %%
cat_feature_indices

# %%
# Configuração dos hiperparâmetros com os melhores valores encontrados
best_hyperparams = {
    'iterations': [100, 200, 300][best['iterations']],  # Seleciona o número de iterações da lista original
    'depth': int(best['depth']),
    'learning_rate': best['learning_rate'],
    'l2_leaf_reg': best['l2_leaf_reg'],
    'class_weights': [{0: 1, 1: 2}, {0: 1, 1: 3}, {0: 1, 1: 5}][best['class_weights']]
}

# Identificar as colunas categóricas
cat_features = X_train.select_dtypes(include=['object', 'category']).columns.tolist()
cat_feature_indices = [X_train.columns.get_loc(col) for col in cat_features]

# Definir o modelo CatBoost com os melhores hiperparâmetros
model_class = CatBoostClassifier(
    iterations=best_hyperparams['iterations'],
    depth=best_hyperparams['depth'],
    learning_rate=best_hyperparams['learning_rate'],
    l2_leaf_reg=best_hyperparams['l2_leaf_reg'],
    eval_metric='AUC',
    logging_level='Silent',
    class_weights=best_hyperparams['class_weights']
)

# Treinamento do modelo com os dados balanceados
modelo_ctb = model_class.fit(X_train, y_train, cat_features=cat_feature_indices)

# %% [markdown]
# ## Analise do Resultado

# %%
import numpy as np
from sklearn.metrics import (
    accuracy_score, confusion_matrix, precision_recall_fscore_support, 
    roc_auc_score, average_precision_score, matthews_corrcoef, log_loss, 
    brier_score_loss, cohen_kappa_score, balanced_accuracy_score
)
from scipy.stats import ks_2samp

# Prever as probabilidades com o modelo de regressão logística
y_pred_proba = result.predict(sm.add_constant(X_test))  # Probabilidade de cada classe
y_pred = (y_pred_proba >= 0.5).astype(int)  # Converter probabilidade para classe (0.5 como limiar)

# Matriz de confusão e cálculos básicos
cm = confusion_matrix(y_test, y_pred)
TN, FP, FN, TP = cm.ravel()
accuracy = accuracy_score(y_test, y_pred)
precision = TP / (TP + FP) if (TP + FP) > 0 else 0
recall = TP / (TP + FN) if (TP + FN) > 0 else 0
f1_score = (2 * precision * recall) / (precision + recall) if (precision + recall) > 0 else 0
specificity = TN / (TN + FP) if (TN + FP) > 0 else 0
fpr = FP / (FP + TN) if (FP + TN) > 0 else 0
fnr = FN / (FN + TP) if (FN + TP) > 0 else 0
balanced_acc = balanced_accuracy_score(y_test, y_pred)

# Métricas baseadas em probabilidades
prauc = average_precision_score(y_test, y_pred_proba)
auc = roc_auc_score(y_test, y_pred_proba)
gini = 2 * auc - 1
mcc = matthews_corrcoef(y_test, y_pred)
log_loss_value = log_loss(y_test, y_pred_proba)
brier_score = brier_score_loss(y_test, y_pred_proba)
kappa = cohen_kappa_score(y_test, y_pred)

# KS Statistic
proba_pos = [p for i, p in enumerate(y_pred_proba) if y_test.iloc[i] == 1]
proba_neg = [p for i, p in enumerate(y_pred_proba) if y_test.iloc[i] == 0]
ks_stat, _ = ks_2samp(proba_pos, proba_neg)

# Top-K Accuracy (Exemplo com K=3)
K = 3
top_k_preds = np.argsort(y_pred_proba, axis=0)[-K:]
top_k_accuracy = np.mean([1 if y_test.iloc[i] in top_k_preds else 0 for i in range(len(y_test))])

# F-beta Score (Exemplo com β=2)
beta = 2
f_beta_score = ((1 + beta**2) * precision * recall) / ((beta**2 * precision) + recall) if (precision + recall) > 0 else 0

# Prevalence Threshold
prevalence = (np.sqrt(recall * (1 - specificity)) + specificity - 1) / (recall + specificity - 1) if (recall + specificity - 1) != 0 else 0

# Exibir as métricas
print(f'Accuracy: {accuracy:.3f}')
print(f'Precision: {precision:.3f}')
print(f'Recall: {recall:.3f}')
print(f'F1-Score: {f1_score:.3f}')
print(f'PRAUC: {prauc:.3f}')
print(f'AUC: {auc:.3f}')
print(f'Gini Coefficient: {gini:.3f}')
print(f'MCC: {mcc:.3f}')
print(f'Log Loss: {log_loss_value:.3f}')
print(f'Brier Score: {brier_score:.3f}')
print(f'Cohen\'s Kappa: {kappa:.3f}')
print(f'KS Statistic: {ks_stat:.3f}')
print(f'Top-{K} Accuracy: {top_k_accuracy:.3f}')
print(f'F-beta Score (β={beta}): {f_beta_score:.3f}')
print(f'Balanced Accuracy: {balanced_acc:.3f}')
print(f'Specificity: {specificity:.3f}')
print(f'False Positive Rate (FPR): {fpr:.3f}')
print(f'False Negative Rate (FNR): {fnr:.3f}')
print(f'Prevalence Threshold: {prevalence:.3f}')

# %% [markdown]
# ### Feature Importance

# %%
# Importância das features
feature_importances = modelo_ctb.get_feature_importance()
sorted_idx = feature_importances.argsort()
plt.figure(figsize=(10, 8))
plt.barh(X_train.columns[sorted_idx], feature_importances[sorted_idx])
plt.title('Importância das Features (CatBoost)')
plt.show()

# %% [markdown]
# #### Treeplot

# %%
# plot single tree
#fig, ax = plt.subplots(figsize=(100, 100))
#fig = plt.figure(figsize=(12, 6))
plt.figure(figsize=(50, 50))
plot_tree(modelo_ctb)
#plt.savefig('xgb_treeplot.jpg', dpi=1800)  
plt.show()

# %% [markdown]
# ### Matriz de Confusão

# %% [markdown]
# O gráfico de calor mostra as previsões do modelo em relação aos valores reais. Os valores na diagonal (7979 e 148171) representam as previsões corretas para as classes negativas (0) e positivas (1), respectivamente. Os outros dois valores (19805 e 18812) representam os erros do tipo I(falsos negativos) e tipo II(falsos positivos), respectivamente. A matriz sugere que o modelo é melhor em prever a classe majoritária (Pontual) do que a minoritária (Atraso), o que é comum em conjuntos de dados desbalanceados.

# %%
# Plot da Matriz de Confusão
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.title('Matriz de Confusão')
plt.xlabel('Predito')
plt.ylabel('Real')
plt.show()

# %% [markdown]
# ### Curva ROC

# %% [markdown]
# A relação entre a taxa de verdadeiro positivo e a taxa de falso positivo para diferentes limiares de classificação. A curva está suave e sobe gradualmente. No entanto, uma curva ROC ideal se aproximaria mais do canto superior esquerdo mais rápido. A consequência é que temos uma alta taxa de verdadeiro positivo e baixa taxa de falso positivo. Isso devido ao banco de dados desbalanceado. O resultado nos permit dizer que ainda há um potencial de melhoria no modelo

# %%
# Curva ROC
y_pred_proba_pos = y_pred_proba[:, 1]
fpr, tpr, thresholds = roc_curve(y_test, y_pred_proba_pos)
plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, label="Curva ROC")
plt.title('Curva ROC')
plt.xlabel('Taxa de Falso Positivo')
plt.ylabel('Taxa de Verdadeiro Positivo')
plt.legend()
plt.show()

# %% [markdown]
# ### Curva de Precisão-Recall

# %% [markdown]
# Este gráfico é útil em situações de classes desbalanceadas e foca na relação entre precisão (quão muitos dos classificados como positivos são realmente positivos) e recall (quão muitos dos positivos reais foram capturados pelo modelo). A curva começa com uma alta precisão, mas diminui à medida que o recall aumenta, isso pode ser um sinal de que pode estar acontecendo um trade-off, ou seja, visando ter mais ou manter performance.

# %%
# Curva de Precisão-Recall
precision, recall, _ = precision_recall_curve(y_test, y_pred_proba_pos)
plt.figure(figsize=(8, 6))
plt.plot(recall, precision, label="Curva de Precisão-Recall")
plt.title('Curva de Precisão-Recall')
plt.xlabel('Recall')
plt.ylabel('Precisão')
plt.legend()
plt.show()

# %% [markdown]
# ### Shap

# %% [markdown]
# O Shap nos permite compreender o peso de cada variavel para o modelo

# %%
# Explicações com SHAP
explainer = shap.TreeExplainer(modelo_ctb)
shap_values = explainer.shap_values(X_test)
shap.summary_plot(shap_values, X_test, plot_type="bar")

# %% [markdown]
# # Statusmodels regressão logistica

# %%
import statsmodels as sm
from statsmodels.tools import add_constant
import statsmodels.api as sm

# %%
file_path = 'df_treinamento_modelo.csv'
df = pd.read_csv(file_path)

df = df.drop(columns =[ 'codigo_di', 'codigo_tipo_linha'])

# %%
# Carrega o arquivo Parquet
#X_smote_a = pd.read_parquet("df_x_train_smote.parquet", engine="pyarrow")
#y_smote_a = pd.read_parquet("df_y_train_smote.parquet", engine="pyarrow")

# %%
#X_test = pd.read_parquet("df_xtest_hold.parquet", engine="pyarrow")
#y_test = pd.read_parquet("df_ytest_hold.parquet", engine="pyarrow")

# %%
X_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 296284 entries, 84946 to 178352
# Data columns (total 29 columns):
#  #   Column                                    Non-Null Count   Dtype
# ---  ------                                    --------------   -----
#  0   nome_empresas                             296284 non-null  int32
#  1   descricao_origem                          296284 non-null  int32
#  2   descricao_destino                         296284 non-null  int32
#  3   cidade_origem                             296284 non-null  int32
#  4   uf_origem                                 296284 non-null  int32
#  5   cidade_destino                            296284 non-null  int32
#  6   uf_destino                                296284 non-null  int32
#  7   mes_partida                               296284 non-null  int32
#  8   dia_semana_partida                        296284 non-null  int32
#  9   dia_mes_partida                           296284 non-null  float64
#  10  hora_partida                              296284 non-null  float64
#  11  latitude_aero_origem                      296284 non-null  float64
#  12  longitude_aero_origem                     296284 non-null  float64
#  13  latitude_aero_destino                     296284 non-null  float64
#  14  longitude_aero_destino                    296284 non-null  float64
#  15  rota                                      296284 non-null  int32
#  16  regiao_origem                             296284 non-null  int32
#  17  precipitacao_total_horario_mm__origem     296284 non-null  float64
#  18  regiao_destino                            296284 non-null  int32
#  19  vento_direcao_horaria_gr_deg_gr__destino  296284 non-null  float64
#  20  numero_empresa_voo                        296284 non-null  int32
#  21  pca_pressao_origem_pca1                   296284 non-null  float64
#  22  pca_umidade_origem_pca1                   296284 non-null  float64
#  23  pca_pressao_destino_pca1                  296284 non-null  float64
#  24  pca_umidade_destino_pca1                  296284 non-null  float64
#  25  pca_temperatura_origem_pca1               296284 non-null  float64
#  26  pca_temperatura_destino_pca1              296284 non-null  float64
#  27  pca_vento_origem_pca1                     296284 non-null  float64
#  28  pca_vento_destino_pca1                    296284 non-null  float64
# dtypes: float64(16), int32(13)
# memory usage: 53.1 MB

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 395046 entries, 0 to 395045
# Data columns (total 30 columns):
#  #   Column                                    Non-Null Count   Dtype
# ---  ------                                    --------------   -----
#  0   nome_empresas                             395046 non-null  int32
#  1   descricao_origem                          395046 non-null  int32
#  2   descricao_destino                         395046 non-null  int32
#  3   status_do_voo                             395046 non-null  int32
#  4   cidade_origem                             395046 non-null  int32
#  5   uf_origem                                 395046 non-null  int32
#  6   cidade_destino                            395046 non-null  int32
#  7   uf_destino                                395046 non-null  int32
#  8   mes_partida                               395046 non-null  int32
#  9   dia_semana_partida                        395046 non-null  int32
#  10  dia_mes_partida                           395046 non-null  float64
#  11  hora_partida                              395046 non-null  float64
#  12  latitude_aero_origem                      395046 non-null  float64
#  13  longitude_aero_origem                     395046 non-null  float64
#  14  latitude_aero_destino                     395046 non-null  float64
#  15  longitude_aero_destino                    395046 non-null  float64
#  16  rota                                      395046 non-null  int32
#  17  regiao_origem                             395046 non-null  int32
#  18  precipitacao_total_horario_mm__origem     395046 non-null  float64
#  19  regiao_destino                            395046 non-null  int32
#  20  vento_direcao_horaria_gr_deg_gr__destino  395046 non-null  float64
#  21  numero_empresa_voo                        395046 non-null  int32
#  22  pca_pressao_origem_pca1                   395046 non-null  float64
#  23  pca_umidade_origem_pca1                   395046 non-null  float64
#  24  pca_pressao_destino_pca1                  395046 non-null  float64
#  25  pca_umidade_destino_pca1                  395046 non-null  float64
#  26  pca_temperatura_origem_pca1               395046 non-null  float64
#  27  pca_temperatura_destino_pca1              395046 non-null  float64
#  28  pca_vento_origem_pca1                     395046 non-null  float64
#  29  pca_vento_destino_pca1                    395046 non-null  float64
# dtypes: float64(16), int32(14)
# memory usage: 69.3 MB

# %%
# Carregar o dataset (substitua pelo seu próprio caminho)
# df = pd.read_csv('seu_dataset.csv')

# Converter colunas categóricas para tipo 'category'
for column in df.select_dtypes(include=['object']).columns:
    df[column] = df[column].astype('category')

# Separar as colunas numéricas e categóricas
numeric_cols = df.select_dtypes(include=['int64', 'float64']).columns
categorical_cols = df.select_dtypes(include=['category']).columns

# Normalizar apenas as colunas numéricas
scaler = StandardScaler()
df[numeric_cols] = scaler.fit_transform(df[numeric_cols])

# Converter as colunas categóricas usando LabelEncoder
label_encoders = {}
for col in categorical_cols:
    le = LabelEncoder()
    df[col] = le.fit_transform(df[col])
    label_encoders[col] = le  # Armazena os label encoders se precisar inverter depois

# Separar variáveis independentes (X) e a variável alvo (y)
X = df.drop(columns=['status_do_voo'])  # Substitua 'status_do_voo' pela sua variável alvo
y = df['status_do_voo']

# Dividir os dados em treino e teste
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=13)

# Adicionar uma constante ao modelo (intercepto)
X_train_const = sm.add_constant(X_train)

# Treinar o modelo de regressão logística
model = sm.Logit(y_train, X_train_const)
result = model.fit()

# Exibir o resumo do modelo
print(result.summary())
# Out:
# Optimization terminated successfully.
#          Current function value: 0.441169
#          Iterations 6
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:          status_do_voo   No. Observations:               296284
# Model:                          Logit   Df Residuals:                   296254
# Method:                           MLE   Df Model:                           29
# Date:                Sun, 17 Nov 2024   Pseudo R-squ.:                 0.03452
# Time:                        17:08:59   Log-Likelihood:            -1.3071e+05
# converged:                       True   LL-Null:                   -1.3538e+05
# Covariance Type:            nonrobust   LLR p-value:                     0.000
# ============================================================================================================
#                                                coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------------
# const                                        1.9069      0.047     40.813      0.000       1.815       1.998
# nome_empresas                               -0.1669      0.025     -6.659      0.000      -0.216      -0.118
# descricao_origem                            -0.0026      0.003     -0.851      0.395      -0.009       0.003
# descricao_destino                            0.0043      0.000     13.216      0.000       0.004       0.005
# cidade_origem                               -0.0003      0.000     -0.639      0.523      -0.001       0.001
# uf_origem                                   -0.0172      0.001    -13.306      0.000      -0.020      -0.015
# cidade_destino                               0.0017      0.000      4.837      0.000       0.001       0.002
# uf_destino                                  -0.0041      0.001     -3.282      0.001      -0.006      -0.002
# mes_partida                                 -0.0044      0.001     -3.073      0.002      -0.007      -0.002
# dia_semana_partida                           0.0017      0.003      0.694      0.487      -0.003       0.007
# dia_mes_partida                              0.0121      0.005      2.440      0.015       0.002       0.022
# hora_partida                                -0.2972      0.006    -46.845      0.000      -0.310      -0.285
# latitude_aero_origem                        -0.0114      0.009     -1.210      0.226      -0.030       0.007
# longitude_aero_origem                        0.0069      0.007      0.985      0.325      -0.007       0.021
# latitude_aero_destino                       -0.0347      0.009     -3.931      0.000      -0.052      -0.017
# longitude_aero_destino                       0.0112      0.006      1.756      0.079      -0.001       0.024
# rota                                         0.0007      0.000      1.761      0.078   -7.92e-05       0.001
# regiao_origem                               -0.0548      0.008     -7.253      0.000      -0.070      -0.040
# precipitacao_total_horario_mm__origem       -0.0439      0.004    -10.473      0.000      -0.052      -0.036
# regiao_destino                              -0.0255      0.007     -3.908      0.000      -0.038      -0.013
# vento_direcao_horaria_gr_deg_gr__destino    -0.0424      0.005     -8.437      0.000      -0.052      -0.033
# numero_empresa_voo                           0.0001   1.85e-05      5.750      0.000       7e-05       0.000
# pca_pressao_origem_pca1                     -0.0571      0.007     -7.935      0.000      -0.071      -0.043
# pca_umidade_origem_pca1                      0.0443      0.007      6.820      0.000       0.032       0.057
# pca_pressao_destino_pca1                    -0.0428      0.007     -6.016      0.000      -0.057      -0.029
# pca_umidade_destino_pca1                    -0.0217      0.006     -3.581      0.000      -0.034      -0.010
# pca_temperatura_origem_pca1                  0.1233      0.009     14.365      0.000       0.107       0.140
# pca_temperatura_destino_pca1                 0.0830      0.008      9.878      0.000       0.067       0.099
# pca_vento_origem_pca1                       -0.0829      0.006    -14.644      0.000      -0.094      -0.072
# pca_vento_destino_pca1                      -0.0956      0.005    -17.863      0.000      -0.106      -0.085
# ============================================================================================================

# %%
# Adicionar uma constante aos dados de teste
X_test = sm.add_constant(X_test)

# Fazer previsões com o modelo ajustado
y_pred = result.predict(X_test)

# Exibir as previsões
print(y_pred)
# Out:
# 235686    0.936497
# 13384     0.762965
# 104306    0.717946
# 220909    0.931062
# 7742      0.921747
#             ...
# 139794    0.749721
# 80342     0.908481
# 204058    0.924502
# 54374     0.799158
# 13646     0.678018
# Length: 98762, dtype: float64

# %%
df
# Out:
# Empty DataFrame
# Columns: [status_do_voo, dia_mes_partida, hora_partida, latitude_aero_origem, longitude_aero_origem, latitude_aero_destino, longitude_aero_destino, precipitacao_total_horario_mm__origem, vento_direcao_horaria_gr_deg_gr__destino, pca_pressao_origem_pca1, pca_umidade_origem_pca1, pca_pressao_destino_pca1, pca_umidade_destino_pca1, pca_temperatura_origem_pca1, pca_temperatura_destino_pca1, pca_vento_origem_pca1, pca_vento_destino_pca1, nome_empresas_GOL, nome_empresas_TAM, descricao_origem_AEROPORTO REGIONAL PLINIO ALARCON, descricao_origem_ALTAMIRA, descricao_origem_ATLAS BRASIL CANTANHEDE, descricao_origem_BAHIA - JORGE AMADO, descricao_origem_BARREIRAS, descricao_origem_BARTOLOMEU LISANDRO, descricao_origem_BAURU/AREALVA, descricao_origem_BRIGADEIRO LYSIAS RODRIGUES, descricao_origem_CABO FRIO, descricao_origem_CACOAL, descricao_origem_CAMPO GRANDE, descricao_origem_CARAJAS, descricao_origem_CATARATAS, descricao_origem_CONGONHAS, descricao_origem_CORONEL ALTINO MACHADO, descricao_origem_CORUMBA, descricao_origem_DEPUTADO LUIS EDUARDO MAGALHAES, descricao_origem_EDUARDO GOMES, descricao_origem_EURICO DE AGUIAR SALLES, descricao_origem_FRANK MILOYE MILENKOVICH, descricao_origem_GENERAL LEITE DE CASTRO, descricao_origem_GOVERNADOR JORGE TEIXEIRA DE OLIVEIRA, descricao_origem_GUANAMBI, descricao_origem_GUARULHOS - GOVERNADOR ANDRE FRANCO MONTORO, descricao_origem_HERCILIO LUZ, descricao_origem_HORACIO DE MATTOS, descricao_origem_HOTEL TRANSAMERICA, descricao_origem_ITAITUBA, descricao_origem_JULIO BELEM, descricao_origem_LAURO CARNEIRO DE LOYOLA, descricao_origem_LAURO KURTZ, descricao_origem_MACAPA, descricao_origem_MAESTRO WILSON FONSECA, descricao_origem_MARECHAL CUNHA MACHADO, descricao_origem_MARIO DE ALMEIDA FRANCO, descricao_origem_MARIO RIBEIRO, descricao_origem_MINISTRO VICTOR KONDER, descricao_origem_NELSON RODRIGUES GUIMARAES, descricao_origem_ORLANDO BEZERRA DE MENEZES, descricao_origem_PATOS DE MINAS, descricao_origem_PELOTAS, descricao_origem_PINTO MARTINS, descricao_origem_PLACIDO DE CASTRO, descricao_origem_PONTA PORA, descricao_origem_PORTO SEGURO, descricao_origem_PREFEITO DOUTOR JOAO SILVA FILHO, descricao_origem_PREFEITO RENATO MOREIRA, descricao_origem_PRESIDENTE JOAO SUASSUNA, descricao_origem_PRESIDENTE JUSCELINO KUBITSCHEK, descricao_origem_PRESIDENTE PRUDENTE, descricao_origem_REGIONAL DE MARINGA - SILVIO NAME JUNIOR, descricao_origem_REGIONAL HUGO CANTERGIANI, descricao_origem_ROMEU ZEMA, descricao_origem_RONDONOPOLIS, descricao_origem_RUBEM BERTA, descricao_origem_SALGADO FILHO, descricao_origem_SANTA GENOVEVA, descricao_origem_SANTA MARIA, descricao_origem_SANTOS DUMONT, descricao_origem_SENADOR NILO COELHO, descricao_origem_SENADOR PETRONIO PORTELLA, descricao_origem_SERAFIN ENOSS BERTASO, descricao_origem_TANCREDO NEVES, descricao_origem_TENENTE-CORONEL AVIADOR CESAR BOMBONATO, descricao_origem_VAL DE CANS, descricao_origem_VIRACOPOS, descricao_destino_AEROPORTO REGIONAL PLINIO ALARCON, descricao_destino_ALTAMIRA, descricao_destino_ATLAS BRASIL CANTANHEDE, descricao_destino_BAHIA - JORGE AMADO, descricao_destino_BARREIRAS, descricao_destino_BARTOLOMEU LISANDRO, descricao_destino_BAURU/AREALVA, descricao_destino_BRIGADEIRO LYSIAS RODRIGUES, descricao_destino_CABO FRIO, descricao_destino_CAMPO GRANDE, descricao_destino_CARAJAS, descricao_destino_CATARATAS, descricao_destino_CONGONHAS, descricao_destino_CORONEL ALTINO MACHADO, descricao_destino_CORUMBA, ...]
# Index: []
#
# [0 rows x 4768 columns]

# %%
# Converter a variável dependente para binária
df['status_do_voo'] = df['status_do_voo'].map({'Pontual': 0, 'Atrasado': 1})

# Checar e corrigir valores nulos
print("Valores nulos por coluna:")
print(df.isnull().sum())
df = df.dropna()  # Remove linhas com valores nulos

# Verificar tipos de dados
print("Tipos de dados:")
print(df.dtypes)

# Transformar colunas categóricas em dummies
categorical_cols = df.select_dtypes(include=['object']).columns  # Identifica colunas categóricas
print("Colunas categóricas:")
print(categorical_cols)

df = pd.get_dummies(df, columns=categorical_cols, drop_first=True)  # Converte em dummies

# Selecionar variáveis independentes e dependente
y = df['status_do_voo']
X = df.drop(columns=['status_do_voo'])

# Dividir os dados em treino e teste
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)

# Adicionar uma constante ao modelo
X_train_const = sm.add_constant(X_train)

# Treinar o modelo de regressão logística
try:
    logit_model = sm.Logit(y_train, X_train_const)
    result = logit_model.fit()
    print(result.summary())
except ValueError as e:
    print("Erro durante o treinamento do modelo:", e)

# Teste no conjunto de teste (opcional)
X_test_const = sm.add_constant(X_test)
y_pred = result.predict(X_test_const)

# Previsões
y_pred_class = (y_pred >= 0.5).astype(int)

# Avaliar métricas
from sklearn.metrics import accuracy_score
print("Acurácia no conjunto de teste:", accuracy_score(y_test, y_pred_class))

# %%
# Converter a variável dependente para binária (se necessário)
#df['status_do_voo'] = df['status_do_voo'].map({'Pontual': 0, 'Atrasado': 1})

# Selecionar variáveis independentes e dependente
y = df['status_do_voo']
X = df.drop(columns=['status_do_voo'])  # Remover a variável dependente do conjunto de preditores

# Transformar variáveis categóricas em dummies
X = pd.get_dummies(X, drop_first=True)

# Dividir os dados em treino e teste
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)

# Adicionar uma constante ao modelo
X_train_const = sm.add_constant(X_train)

# Treinar o modelo de regressão logística
logit_model = sm.Logit(y_train, X_train_const)
result = logit_model.fit()

# Resumo do modelo
print(result.summary())

# Avaliar o modelo no conjunto de teste
X_test_const = sm.add_constant(X_test)
y_pred = result.predict(X_test_const)

# Converter previsões em classes binárias
y_pred_class = (y_pred >= 0.5).astype(int)

# Calcular métricas de avaliação
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

print("Accuracy:", accuracy_score(y_test, y_pred_class))
print("Precision:", precision_score(y_test, y_pred_class))
print("Recall:", recall_score(y_test, y_pred_class))
print("F1 Score:", f1_score(y_test, y_pred_class))

# %% [markdown]
# ## Analise do Resultado

# %% [markdown]
# ### Metricas

# %%
import numpy as np
from sklearn.metrics import (
    accuracy_score, confusion_matrix, precision_recall_fscore_support, 
    roc_auc_score, average_precision_score, matthews_corrcoef, log_loss, 
    brier_score_loss, cohen_kappa_score, balanced_accuracy_score
)
from scipy.stats import ks_2samp

# Prever as probabilidades com o modelo de regressão logística
y_pred_proba = result.predict(sm.add_constant(X_test))  # Probabilidade de cada classe
y_pred = (y_pred_proba >= 0.5).astype(int)  # Converter probabilidade para classe (0.5 como limiar)

# Matriz de confusão e cálculos básicos
cm = confusion_matrix(y_test, y_pred)
TN, FP, FN, TP = cm.ravel()
accuracy = accuracy_score(y_test, y_pred)
precision = TP / (TP + FP) if (TP + FP) > 0 else 0
recall = TP / (TP + FN) if (TP + FN) > 0 else 0
f1_score = (2 * precision * recall) / (precision + recall) if (precision + recall) > 0 else 0
specificity = TN / (TN + FP) if (TN + FP) > 0 else 0
fpr = FP / (FP + TN) if (FP + TN) > 0 else 0
fnr = FN / (FN + TP) if (FN + TP) > 0 else 0
balanced_acc = balanced_accuracy_score(y_test, y_pred)

# Métricas baseadas em probabilidades
prauc = average_precision_score(y_test, y_pred_proba)
auc = roc_auc_score(y_test, y_pred_proba)
gini = 2 * auc - 1
mcc = matthews_corrcoef(y_test, y_pred)
log_loss_value = log_loss(y_test, y_pred_proba)
brier_score = brier_score_loss(y_test, y_pred_proba)
kappa = cohen_kappa_score(y_test, y_pred)

# KS Statistic
proba_pos = [p for i, p in enumerate(y_pred_proba) if y_test.iloc[i] == 1]
proba_neg = [p for i, p in enumerate(y_pred_proba) if y_test.iloc[i] == 0]
ks_stat, _ = ks_2samp(proba_pos, proba_neg)

# Top-K Accuracy (Exemplo com K=3)
K = 3
top_k_preds = np.argsort(y_pred_proba, axis=0)[-K:]
top_k_accuracy = np.mean([1 if y_test.iloc[i] in top_k_preds else 0 for i in range(len(y_test))])

# F-beta Score (Exemplo com β=2)
beta = 2
f_beta_score = ((1 + beta**2) * precision * recall) / ((beta**2 * precision) + recall) if (precision + recall) > 0 else 0

# Prevalence Threshold
prevalence = (np.sqrt(recall * (1 - specificity)) + specificity - 1) / (recall + specificity - 1) if (recall + specificity - 1) != 0 else 0

# Geometric Mean (G-Mean)
g_mean = np.sqrt(sensitivity * specificity)

# Exibir as métricas
print(f'Accuracy: {accuracy:.3f}')
print(f'Precision: {precision:.3f}')
print(f'Recall: {recall:.3f}')
print(f'F1-Score: {f1_score:.3f}')
print(f'PRAUC: {prauc:.3f}')
print(f'AUC: {auc:.3f}')
print(f'Gini Coefficient: {gini:.3f}')
print(f'MCC: {mcc:.3f}')
print(f'Log Loss: {log_loss_value:.3f}')
print(f'Brier Score: {brier_score:.3f}')
print(f'Cohen\'s Kappa: {kappa:.3f}')
print(f'KS Statistic: {ks_stat:.3f}')
print(f'Top-{K} Accuracy: {top_k_accuracy:.3f}')
print(f'F-beta Score (β={beta}): {f_beta_score:.3f}')
print(f'Balanced Accuracy: {balanced_acc:.3f}')
print(f'Specificity: {specificity:.3f}')
print(f'False Positive Rate (FPR): {fpr:.3f}')
print(f'False Negative Rate (FNR): {fnr:.3f}')
print(f'Prevalence Threshold: {prevalence:.3f}')
print(f'G-means: {g_mean:.3f}')
# Out:
# Accuracy: 0.830
# Precision: 0.830
# Recall: 1.000
# F1-Score: 0.907
# PRAUC: 0.887
# AUC: 0.634
# Gini Coefficient: 0.267
# MCC: 0.007
# Log Loss: 0.440
# Brier Score: 0.136
# Cohen's Kappa: 0.001
# KS Statistic: 0.188
# Top-3 Accuracy: 0.000
# F-beta Score (β=2): 0.960
# Balanced Accuracy: 0.500
# Specificity: 0.001
# False Positive Rate (FPR): 0.999
# False Negative Rate (FNR): 0.000
# Prevalence Threshold: 0.500
# G-means: 0.025

# %% [markdown]
# ### Matriz de Confusão

# %% [markdown]
# O gráfico de calor mostra as previsões do modelo em relação aos valores reais. Os valores na diagonal (7979 e 148171) representam as previsões corretas para as classes negativas (0) e positivas (1), respectivamente. Os outros dois valores (19805 e 18812) representam os erros do tipo I(falsos negativos) e tipo II(falsos positivos), respectivamente. A matriz sugere que o modelo é melhor em prever a classe majoritária (Pontual) do que a minoritária (Atraso), o que é comum em conjuntos de dados desbalanceados.

# %%
# Exibir a matriz de confusão com heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap="Blues", cbar=False)
plt.title('Matriz de Confusão')
plt.xlabel('Previsto')
plt.ylabel('Real')
plt.show()

# %% [markdown]
# ### Curva ROC

# %% [markdown]
# A relação entre a taxa de verdadeiro positivo e a taxa de falso positivo para diferentes limiares de classificação. A curva está suave e sobe gradualmente. No entanto, uma curva ROC ideal se aproximaria mais do canto superior esquerdo mais rápido. A consequência é que temos uma alta taxa de verdadeiro positivo e baixa taxa de falso positivo. Isso devido ao banco de dados desbalanceado. O resultado nos permit dizer que ainda há um potencial de melhoria no modelo

# %%
# Curva ROC
fpr, tpr, thresholds = roc_curve(y_test, y_pred_proba)
plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, label='Curva ROC')
plt.plot([0, 1], [0, 1], 'k--')
plt.title('Curva ROC')
plt.xlabel('Taxa de Falso Positivo')
plt.ylabel('Taxa de Verdadeiro Positivo')
plt.legend()
plt.show()

# %% [markdown]
# ### Curva de Precisão-Recall

# %% [markdown]
# Este gráfico é útil em situações de classes desbalanceadas e foca na relação entre precisão (quão muitos dos classificados como positivos são realmente positivos) e recall (quão muitos dos positivos reais foram capturados pelo modelo). A curva começa com uma alta precisão, mas diminui à medida que o recall aumenta, isso pode ser um sinal de que pode estar acontecendo um trade-off, ou seja, visando ter mais ou manter performance.

# %%
precision_curve, recall_curve, _ = precision_recall_curve(y_test, y_pred_proba)
plt.figure(figsize=(8, 6))
plt.plot(recall_curve, precision_curve, label='Curva de Precisão-Recall')
plt.title('Curva de Precisão-Recall')
plt.xlabel('Recall')
plt.ylabel('Precisão')
plt.legend()
plt.show()

# %% [markdown]
# # Xgboost Undersampling

# %%
# Bibliotecas padrão e de manipulação de data
from datetime import date
import pandas as pd
import numpy as np
from pytz import timezone

# Visualização de dados
import seaborn as sns
import matplotlib.pyplot as plt
import scikitplot as skplt

# Machine Learning - pré-processamento e métricas
from sklearn import preprocessing
from sklearn.preprocessing import LabelEncoder, OneHotEncoder, StandardScaler
from sklearn.model_selection import train_test_split, cross_val_score, RepeatedStratifiedKFold, KFold, StratifiedKFold
from sklearn.pipeline import Pipeline
from sklearn.metrics import accuracy_score, f1_score, confusion_matrix, roc_auc_score, recall_score, precision_score, log_loss, average_precision_score
from sklearn.metrics import roc_curve, precision_recall_curve

# Machine Learning - modelos e otimização
import xgboost as xgb
from xgboost import plot_importance
from xgboost import plot_tree
import sklearn
import shap
from hyperopt import fmin, tpe, hp, Trials, STATUS_OK, space_eval
from skopt import forest_minimize
from imblearn.over_sampling import SMOTE
from imblearn.pipeline import make_pipeline

# Salvamento e carregamento de modelos
import pickle
import os

# Outras bibliotecas
import re

plt.style.use('ggplot')
print(xgb.__version__)
print(shap.__version__)
print(sklearn.__version__)
#print(hyperopt.__version__)
# Out:
# 2.0.2
# 0.44.0
# 1.4.2

# %%
file_path_x = 'df_x_train.csv'
X_train = pd.read_csv(file_path_x)

file_path_y = 'df_y_train.csv'
y_train = pd.read_csv(file_path_y)

# %%
# Aplicação do RandomUnderSampler nos dados de treino
undersample = RandomUnderSampler(random_state=42)
X_resampled, y_resampled = undersample.fit_resample(X_train, y_train)

# %%
X_resampled.to_parquet("df_x_train_undersamp.parquet", index=False, engine="pyarrow")
y_resampled.to_parquet("df_y_train_undersamp.parquet", index=False, engine="pyarrow")

# Salvar em CSV
#X_train_calib.to_parquet("df_x_train_calib.csv", index=False)
#X_test_calib.to_parquet("df_xtest_calib.csv", index=False)
#y_train_calib.to_parquet("df_y_train_calib.csv", index=False)
#y_test_calib.to_parquet("df_ytest_calib.csv", index=False)

# %%
def print_class_distribution(y, label):
    unique, counts = np.unique(y, return_counts=True)
    distribution = dict(zip(unique, counts))
    total = sum(counts)
    print(f'Distribuição de classes {label}:')
    for k, v in distribution.items():
        print(f'Classe {k}: {v/total:.2%}')
    print('--------------------')

print_class_distribution(y_train, 'original')
print_class_distribution(y_resampled, 'SMOTE')
# Out:
# Distribuição de classes original:
# Classe 0: 82.96%
# Classe 1: 17.04%
# --------------------
# Distribuição de classes SMOTE:
# Classe 0: 50.00%
# Classe 1: 50.00%
# --------------------

# %%
# Carrega o arquivo Parquet
X_resampled = pd.read_parquet("df_x_train_undersamp.parquet", engine="pyarrow")
y_resampled = pd.read_parquet("df_y_train_undersamp.parquet", engine="pyarrow")

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
import xgboost as xgb

file_path = 'df_treinamento_modelo.csv'
df = pd.read_csv(file_path)

df = df.drop(columns =[ 'codigo_di', 'codigo_tipo_linha'])

# Transformar colunas categóricas em tipo "category"
df[list_dummies] = df[list_dummies].astype("category")

# Seleção das features preditoras (X) e variável-alvo (y)
dt_ax = df.drop(columns=["status_do_voo"])
dt_ay = df[['status_do_voo']]

# Codificação da variável-alvo
label_mapping = {'Pontual': 0, 'Atrasado': 1}
dt_ay = dt_ay['status_do_voo'].map(label_mapping)

# Codifica colunas categóricas como inteiros
label_encoders = {}
for col in list_dummies:
    le = LabelEncoder()
    dt_ax[col] = le.fit_transform(dt_ax[col])
    label_encoders[col] = le

# Segmentação em treino (85%) e teste (15%)
X_train, X_test, y_train, y_test = train_test_split(dt_ax, dt_ay, random_state=13, test_size=0.15)

#smote = SMOTE(random_state=42, sampling_strategy='not majority')
#X_smote_a, y_smote_a = smote.fit_resample(X_train, y_train)

# Segmentação adicional para calibração (75% treino / 25% calibração)
X_train_calib, X_test_calib, y_train_calib, y_test_calib = train_test_split(X_train, y_train, random_state=13, test_size=0.25)

smote = RandomUnderSampler(random_state=42)
X_smote_a, y_smote_a = smote.fit_resample(X_train_calib, y_train_calib)

# Reverter os valores transformados para o tipo "category" original
def revert_to_category(data, label_encoders, list_dummies):
    for col in list_dummies:
        if col in data.columns:
            le = label_encoders[col]
            data[col] = le.inverse_transform(data[col])
    return data

# Aplicar a reversão em X_smote_a, X_test_calib, X_test
X_smote_a = revert_to_category(X_smote_a, label_encoders, list_dummies)
X_test_calib = revert_to_category(X_test_calib, label_encoders, list_dummies)
X_test = revert_to_category(X_test, label_encoders, list_dummies)

# Para garantir que as colunas estão no tipo "category"
X_smote_a[list_dummies] = X_smote_a[list_dummies].astype("category")
X_test_calib[list_dummies] = X_test_calib[list_dummies].astype("category")
X_test[list_dummies] = X_test[list_dummies].astype("category")

# Converte os nomes das colunas para uma lista de strings
feature_names = list(X_test.columns)

# Converte os conjuntos para DMatrix
dtrain_calib = xgb.DMatrix(X_smote_a, label=y_smote_a, enable_categorical=True, feature_names=feature_names, nthread=-1)
dtest_calib = xgb.DMatrix(X_test_calib, label=y_test_calib, enable_categorical=True, feature_names=feature_names, nthread=-1)

# Converte os conjuntos para DMatrix
#dtrain = xgb.DMatrix(X_smote_a, label=y_smote_a, enable_categorical=True, feature_names=feature_names)
dtest = xgb.DMatrix(X_test, label=y_test, enable_categorical=True, feature_names=feature_names, nthread=-1)

# %%
def print_class_distribution(y, label):
    unique, counts = np.unique(y, return_counts=True)
    distribution = dict(zip(unique, counts))
    total = sum(counts)
    print(f'Distribuição de classes {label}:')
    for k, v in distribution.items():
        print(f'Classe {k}: {v/total:.2%}')
    print('--------------------')

print_class_distribution(y_train, 'original')
print_class_distribution(y_smote_a, 'SMOTE')
# Out:
# Distribuição de classes original:
# Classe 0: 82.96%
# Classe 1: 17.04%
# --------------------
# Distribuição de classes SMOTE:
# Classe 0: 50.00%
# Classe 1: 50.00%
# --------------------

# %%
def hipertunnig(space):
    """
    Realiza o ajuste de hiperparâmetros de um modelo XGBoost usando validação cruzada com DMatrix.
    
    Args:
    space (dict): Dicionário contendo os hiperparâmetros avaliados pelo Hyperopt.
    
    Returns:
    dict: Dicionário contendo o 'loss' (negativo da média do AUCPR), o 'status' e as métricas adicionais (AUC).
    """
    # Configuração do modelo com os parâmetros do espaço
    params = {
        'max_depth': int(space['max_depth']),
        'gamma': space['gamma'],
        'reg_alpha': space['reg_alpha'],
        'reg_lambda': space['reg_lambda'],
        'min_child_weight': int(space['min_child_weight']),
        'colsample_bytree': space['colsample_bytree'],
        'learning_rate': space['learning_rate'],
        'max_delta_step': space['max_delta_step'],
        'subsample': space['subsample'],
        'sampling_method': space['sampling_method'],
        'tree_method': space['tree_method'],       
        'device': space['device'], 
        'enable_categorical': space['enable_categorical'],
        'scale_pos_weight': space['scale_pos_weight'],
        'eval_metric': ["aucpr", "auc"],  # Avalia AUCPR e AUC
        'objective': space['objective'],
        'seed': space['seed'],
        'random_state': space['seed'],
        'max_cat_to_onehot': int(space['max_cat_to_onehot']),
        'max_cat_threshold': int(space['max_cat_threshold']),  
        'validate_parameters': space['validate_parameters']
    }

    # Realiza a validação cruzada com xgb.cv
    cv_results = xgb.cv(
        params=params,
        dtrain=dtrain_calib,                  # DMatrix preparado
        num_boost_round=int(space['n_estimators']),
        nfold=5,                              # Número de folds
        metrics=["aucpr", "auc"],             # Métricas de avaliação
        as_pandas=True,                       # Retorna os resultados como DataFrame
        seed=42,
        stratified=True,                      # Garante estratificação
        early_stopping_rounds = 10,           # Ativa a parada antecipada
    )
    
    # Calcula a média do AUCPR e do AUC
    mean_aucpr = cv_results["test-aucpr-mean"].max()
    mean_auc = cv_results["test-auc-mean"].max()
    print("Média AUCPR: ", mean_aucpr)
    print("Média AUC: ", mean_auc)

    # Retorna os resultados
    return {
        'loss': -mean_aucpr,   # Usa o negativo do AUCPR como função de perda
        'status': STATUS_OK,
        'additional_metrics': {
            'aucpr': mean_aucpr,
            'auc': mean_auc}}

# Espaço de busca atualizado
space = {
    'max_depth': scope.int(hp.quniform("max_depth", 1, 15, 1)),
    'gamma': hp.uniform('gamma', 1, 20),
    'reg_alpha': scope.int(hp.quniform('reg_alpha', 0, 200, 1)),
    'reg_lambda': hp.uniform('reg_lambda', 0, 10),
    'colsample_bytree': hp.uniform('colsample_bytree', 0.1, 1),
    'min_child_weight': scope.int(hp.quniform('min_child_weight', 0, 20, 1)),
    'learning_rate': hp.uniform('learning_rate', 0.01, 0.5),
    'n_estimators': scope.int(hp.quniform('n_estimators', 50, 1000, 10)),
    'max_delta_step': hp.uniform('max_delta_step', 0, 10),
    'subsample': hp.uniform('subsample', 0.3, 1),
    'sampling_method': 'gradient_based',
    'tree_method': 'hist',
    'device': 'cuda',
    'enable_categorical': True,
    'scale_pos_weight': hp.uniform('scale_pos_weight', 1, 10),
    'max_cat_to_onehot': scope.int(hp.quniform('max_cat_to_onehot', 3, 50, 1)),
    'max_cat_threshold': scope.int(hp.quniform('max_cat_threshold', 3, 50, 1)),
    'validate_parameters': True,
    'seed': 0,
    'objective': 'binary:logistic'
}

# %%
# Executando a otimização
trials = Trials()
best_hyperparams = fmin(fn=hipertunnig, 
                        space=space, 
                        algo=tpe.suggest, 
                        max_evals=2, 
                        trials=trials)

# Obtendo os melhores hiperparâmetros
best_hyperparams = space_eval(space, best_hyperparams)
print("Melhores hiperparâmetros:", best_hyperparams)
# Out:
#   0%|                                                                            | 0/2 [00:00<?, ?trial/s, best loss=?]
# [23:09:01] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0750514818a16474a-1\xgboost\xgboost-ci-windows\src\learner.cc:742:
# Parameters: { "enable_categorical" } are not used.
#
#
# [23:09:02] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0750514818a16474a-1\xgboost\xgboost-ci-windows\src\learner.cc:742:
# Parameters: { "enable_categorical" } are not used.
# Média AUCPR:
# 0.6850846148413265
# Média AUC:
# 0.6991766623029618
#  50%|████████████████████████▌                        | 1/2 [00:06<00:06,  6.44s/trial, best loss: -0.6850846148413265]
# [23:09:08] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0750514818a16474a-1\xgboost\xgboost-ci-windows\src\learner.cc:742:
# Parameters: { "enable_categorical" } are not used.
# Média AUCPR:
# 0.6978768389944684
# Média AUC:
# 0.7090477196523842
# 100%|█████████████████████████████████████████████████| 2/2 [00:09<00:00,  4.92s/trial, best loss: -0.6978768389944684]
# Melhores hiperparâmetros: {'colsample_bytree': 0.4842751971230236, 'device': 'cuda', 'enable_categorical': True, 'gamma': 15.043778234491203, 'learning_rate': 0.4064510679336643, 'max_cat_threshold': 22, 'max_cat_to_onehot': 15, 'max_delta_step': 9.043341980933928, 'max_depth': 6, 'min_child_weight': 11, 'n_estimators': 250, 'objective': 'binary:logistic', 'reg_alpha': 74, 'reg_lambda': 2.009062002629962, 'sampling_method': 'gradient_based', 'scale_pos_weight': 8.714192552979657, 'seed': 0, 'subsample': 0.7494984752793321, 'tree_method': 'hist', 'validate_parameters': True}

# %%
best_hyperparams
# Out:
# {'colsample_bytree': 0.4842751971230236,
#  'device': 'cuda',
#  'enable_categorical': True,
#  'gamma': 15.043778234491203,
#  'learning_rate': 0.4064510679336643,
#  'max_cat_threshold': 22,
#  'max_cat_to_onehot': 15,
#  'max_delta_step': 9.043341980933928,
#  'max_depth': 6,
#  'min_child_weight': 11,
#  'n_estimators': 250,
#  'objective': 'binary:logistic',
#  'reg_alpha': 74,
#  'reg_lambda': 2.009062002629962,
#  'sampling_method': 'gradient_based',
#  'scale_pos_weight': 8.714192552979657,
#  'seed': 0,
#  'subsample': 0.7494984752793321,
#  'tree_method': 'hist',
#  'validate_parameters': True}

# %%
# Carrega o arquivo Parquet
#X_resampled = pd.read_parquet("df_x_train_undersamp.parquet", engine="pyarrow")
#y_resampled = pd.read_parquet("df_y_train_undersamp.parquet", engine="pyarrow")

# %%
# Preparar os parâmetros do modelo
best_params = {
    'max_depth': int(best_hyperparams['max_depth']),               # Profundidade máxima da árvore
    'n_estimators': int(best_hyperparams['n_estimators']),         # Número de árvores (boost rounds)
    'reg_lambda': best_hyperparams['reg_lambda'],                  # Regularização L2
    'reg_alpha': best_hyperparams['reg_alpha'],                    # Regularização L1
    'gamma': best_hyperparams['gamma'],                            # Redução mínima da perda
    'min_child_weight': int(best_hyperparams['min_child_weight']), # Peso mínimo da folha
    'colsample_bytree': best_hyperparams['colsample_bytree'],      # Amostragem de colunas por árvore
    'learning_rate': best_hyperparams['learning_rate'],            # Taxa de aprendizado
    'max_delta_step': best_hyperparams['max_delta_step'],          # Passo máximo de atualização
    'subsample': best_hyperparams['subsample'],                    # Fração de amostras para cada árvore
    'sampling_method': best_hyperparams['sampling_method'],        # Método de amostragem (e.g., 'uniform' ou 'gradient_based')
    'tree_method': best_hyperparams['tree_method'],                # Método de crescimento da árvore ('hist', 'gpu_hist', etc.)
    'scale_pos_weight': best_hyperparams['scale_pos_weight'],      # Peso para classes desbalanceadas
    'max_cat_to_onehot': best_hyperparams['max_cat_to_onehot'],    # Número máximo de categorias para one-hot
    'max_cat_threshold': best_hyperparams.get('max_cat_threshold', 20), # Limite máximo de categorias (valor padrão incluído)
    'objective': 'binary:logistic',                                # Objetivo do modelo (logística binária)
    'eval_metric': ["aucpr", "auc"],                               # Métrica de avaliação padrão
    'enable_categorical': True,                                    # Suporte a variáveis categóricas
    'validate_parameters': True,                                   # Validação dos parâmetros
    'seed': best_hyperparams.get('seed', 0),                       # Semente para reprodutibilidade
    'random_state': best_hyperparams.get('random_state', 0),       # Estado aleatório
    'device': best_hyperparams.get('device', 'cuda'),              # Especifica o uso de GPU ('cuda' ou 'cpu')
    'verbosity': 1,                                                # Nível de logging do modelo
    'nthread': best_hyperparams.get('nthread', -1)                 # Número de threads para paralelismo
}

# Separar o número de iterações de boosting
num_boost_round = best_params.pop('n_estimators')  # Remove do dict e armazena separadamente

# Treinamento com early stopping
modelo_under_samp = xgb.train(
    params=best_params,
    dtrain=dtrain_calib,
    num_boost_round=num_boost_round,
    evals=[(dtest, 'validation')],  # Adiciona o conjunto de validação
    early_stopping_rounds=13,      # Critério de parada
    verbose_eval=True              # Mostra o progresso durante o treinamento
)
# Out:
# [23:09:41] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0750514818a16474a-1\xgboost\xgboost-ci-windows\src\learner.cc:742:
# Parameters: { "enable_categorical" } are not used.
# [0]	validation-aucpr:0.21957	validation-auc:0.59155
# [1]	validation-aucpr:0.26785	validation-auc:0.65330
# [2]	validation-aucpr:0.26436	validation-auc:0.65756
# [3]	validation-aucpr:0.27214	validation-auc:0.66824
# [4]	validation-aucpr:0.29165	validation-auc:0.67612
# [5]	validation-aucpr:0.29586	validation-auc:0.67780
# [6]	validation-aucpr:0.30211	validation-auc:0.68081
# [7]	validation-aucpr:0.30669	validation-auc:0.68384
# [8]	validation-aucpr:0.30942	validation-auc:0.68569
# [9]	validation-aucpr:0.31431	validation-auc:0.69001
# [10]	validation-aucpr:0.31640	validation-auc:0.69183
# [11]	validation-aucpr:0.31708	validation-auc:0.69215
# [12]	validation-aucpr:0.31897	validation-auc:0.69318
# [13]	validation-aucpr:0.32020	validation-auc:0.69397
# [14]	validation-aucpr:0.32798	validation-auc:0.69775
# [15]	validation-aucpr:0.33027	validation-auc:0.70041
# [16]	validation-aucpr:0.33112	validation-auc:0.70113
# [17]	validation-aucpr:0.33177	validation-auc:0.70156
# [18]	validation-aucpr:0.33156	validation-auc:0.70195
# [19]	validation-aucpr:0.33175	validation-auc:0.70264
# [20]	validation-aucpr:0.33134	validation-auc:0.70234
# [21]	validation-aucpr:0.33161	validation-auc:0.70261
# [22]	validation-aucpr:0.33170	validation-auc:0.70293
# [23]	validation-aucpr:0.33339	validation-auc:0.70423
# [24]	validation-aucpr:0.33579	validation-auc:0.70524
# [25]	validation-aucpr:0.33603	validation-auc:0.70562
# [26]	validation-aucpr:0.33645	validation-auc:0.70628
# [27]	validation-aucpr:0.33676	validation-auc:0.70654
# [28]	validation-aucpr:0.33675	validation-auc:0.70658
# [29]	validation-aucpr:0.33731	validation-auc:0.70689
# [30]	validation-aucpr:0.33785	validation-auc:0.70720
# [31]	validation-aucpr:0.33785	validation-auc:0.70720
# [32]	validation-aucpr:0.33785	validation-auc:0.70720
# [33]	validation-aucpr:0.33785	validation-auc:0.70720
# [34]	validation-aucpr:0.33785	validation-auc:0.70720
# [35]	validation-aucpr:0.33769	validation-auc:0.70717
# [36]	validation-aucpr:0.33769	validation-auc:0.70717
# [37]	validation-aucpr:0.33834	validation-auc:0.70736
# [38]	validation-aucpr:0.33834	validation-auc:0.70736
# [39]	validation-aucpr:0.33834	validation-auc:0.70736
# [40]	validation-aucpr:0.33834	validation-auc:0.70736
# [41]	validation-aucpr:0.33843	validation-auc:0.70739
# [42]	validation-aucpr:0.33878	validation-auc:0.70751
# [43]	validation-aucpr:0.33878	validation-auc:0.70751
# [44]	validation-aucpr:0.33878	validation-auc:0.70751
# [45]	validation-aucpr:0.33878	validation-auc:0.70751
# [46]	validation-aucpr:0.33878	validation-auc:0.70751
# [47]	validation-aucpr:0.33880	validation-auc:0.70751
# [48]	validation-aucpr:0.33880	validation-auc:0.70751
# [49]	validation-aucpr:0.33877	validation-auc:0.70755
# [50]	validation-aucpr:0.33858	validation-auc:0.70750
# [51]	validation-aucpr:0.33861	validation-auc:0.70755
# [52]	validation-aucpr:0.33861	validation-auc:0.70755
# [53]	validation-aucpr:0.33814	validation-auc:0.70753
# [54]	validation-aucpr:0.33814	validation-auc:0.70753
# [55]	validation-aucpr:0.33814	validation-auc:0.70753
# [56]	validation-aucpr:0.33837	validation-auc:0.70763
# [57]	validation-aucpr:0.33837	validation-auc:0.70763
# [58]	validation-aucpr:0.33837	validation-auc:0.70763
# [59]	validation-aucpr:0.33837	validation-auc:0.70763
# [60]	validation-aucpr:0.33837	validation-auc:0.70763
# [61]	validation-aucpr:0.33837	validation-auc:0.70763
# [62]	validation-aucpr:0.33837	validation-auc:0.70763
# [63]	validation-aucpr:0.33837	validation-auc:0.70763
# [64]	validation-aucpr:0.33837	validation-auc:0.70763
# [65]	validation-aucpr:0.34018	validation-auc:0.70885
# [66]	validation-aucpr:0.34018	validation-auc:0.70883
# [67]	validation-aucpr:0.34034	validation-auc:0.70890
# [68]	validation-aucpr:0.34034	validation-auc:0.70890
# [69]	validation-aucpr:0.34034	validation-auc:0.70890
# [70]	validation-aucpr:0.34034	validation-auc:0.70890
# [71]	validation-aucpr:0.34034	validation-auc:0.70890
# [72]	validation-aucpr:0.34035	validation-auc:0.70886
# [73]	validation-aucpr:0.34035	validation-auc:0.70886
# [74]	validation-aucpr:0.34029	validation-auc:0.70883
# [75]	validation-aucpr:0.34029	validation-auc:0.70883
# [76]	validation-aucpr:0.34029	validation-auc:0.70883
# [77]	validation-aucpr:0.34029	validation-auc:0.70883
# [78]	validation-aucpr:0.34029	validation-auc:0.70883
# [79]	validation-aucpr:0.34029	validation-auc:0.70883
# [80]	validation-aucpr:0.34029	validation-auc:0.70883
# [81]	validation-aucpr:0.34029	validation-auc:0.70883
# [82]	validation-aucpr:0.34029	validation-auc:0.70883

# %%
# Salvar o modelo
save_pickle(modelo_under_samp, 'modelo/model_class_undersamp.pkl')

# %% [markdown]
# ## Analise do Resultado

# %% [markdown]
# ### Mertricas

# %%
import numpy as np
from sklearn.metrics import (
    accuracy_score, confusion_matrix, precision_score, recall_score,
    f1_score, roc_auc_score, balanced_accuracy_score, average_precision_score,
    log_loss, brier_score_loss, cohen_kappa_score, matthews_corrcoef
)

# Garantir que y_test e y_pred_proba sejam arrays NumPy
y_test_np = np.array(y_test_calib)  # Converte y_test para NumPy se necessário
y_pred_proba = modelo_under_samp.predict(dtest_calib)  # Previsões no formato de probabilidades da classe positiva

# Prever as classes com base no limiar de 0.5
y_pred = (y_pred_proba >= 0.5).astype(int)

# Matriz de confusão e cálculos básicos
cm = confusion_matrix(y_test_np, y_pred)
TN, FP, FN, TP = cm.ravel()
accuracy = accuracy_score(y_test_np, y_pred)
sensitivity = TP / (TP + FN) if (TP + FN) > 0 else 0
specificity = TN / (TN + FP) if (TN + FP) > 0 else 0
precision = TP / (TP + FP) if (TP + FP) > 0 else 0
recall = sensitivity
f1 = (2 * precision * recall) / (precision + recall) if (precision + recall) > 0 else 0
balanced_acc = balanced_accuracy_score(y_test_np, y_pred)
fpr = FP / (FP + TN) if (FP + TN) > 0 else 0
fnr = FN / (FN + TP) if (FN + TP) > 0 else 0

# Métricas baseadas em probabilidades
prauc = average_precision_score(y_test_np, y_pred_proba)
auc = roc_auc_score(y_test_np, y_pred_proba)
gini = 2 * auc - 1
mcc = matthews_corrcoef(y_test_np, y_pred)
log_loss_value = log_loss(y_test_np, y_pred_proba)
brier_score = brier_score_loss(y_test_np, y_pred_proba)
kappa = cohen_kappa_score(y_test_np, y_pred)

# Geometric Mean (G-Mean)
g_mean = np.sqrt(sensitivity * specificity)

# Exibir as métricas
print(f'Accuracy: {accuracy:.3f}')
print(f'Precision: {precision:.3f}')
print(f'Recall: {recall:.3f}')
print(f'F1-Score: {f1:.3f}')
print(f'PRAUC: {prauc:.3f}')
print(f'AUC: {auc:.3f}')
print(f'Gini Coefficient: {gini:.3f}')
print(f'MCC: {mcc:.3f}')
print(f'Log Loss: {log_loss_value:.3f}')
print(f'Brier Score: {brier_score:.3f}')
print(f'Cohen\'s Kappa: {kappa:.3f}')
print(f'Balanced Accuracy: {balanced_acc:.3f}')
print(f'Specificity: {specificity:.3f}')
print(f'False Positive Rate (FPR): {fpr:.3f}')
print(f'False Negative Rate (FNR): {fnr:.3f}')
print(f'Geometric Mean (G-Mean): {g_mean:.3f}')
# Out:
# Accuracy: 0.182
# Precision: 0.172
# Recall: 0.999
# F1-Score: 0.294
# PRAUC: 0.354
# AUC: 0.712
# Gini Coefficient: 0.425
# MCC: 0.045
# Log Loss: 1.699
# Brier Score: 0.598
# Cohen's Kappa: 0.004
# Balanced Accuracy: 0.506
# Specificity: 0.014
# False Positive Rate (FPR): 0.986
# False Negative Rate (FNR): 0.001
# Geometric Mean (G-Mean): 0.118

# %% [markdown]
# ### Feature Importance

# %%
plt.rcParams['figure.figsize'] = [13, 9]
xgb.plot_importance(modelo_under_samp, max_num_features=20)
plt.show()

# %% [markdown]
# #### Treeplot

# %%
# plot single tree
#fig, ax = plt.subplots(figsize=(100, 100))
#fig = plt.figure(figsize=(12, 6))
plt.figure(figsize=(50, 50))
plot_tree(modelo_under_samp)
#plt.savefig('xgb_treeplot.jpg', dpi=1800)  
plt.show()

# %% [markdown]
# ### Matriz de Confusão

# %% [markdown]
# O gráfico de calor mostra as previsões do modelo em relação aos valores reais. Os valores na diagonal (7979 e 148171) representam as previsões corretas para as classes negativas (0) e positivas (1), respectivamente. Os outros dois valores (19805 e 18812) representam os erros do tipo I(falsos negativos) e tipo II(falsos positivos), respectivamente. A matriz sugere que o modelo é melhor em prever a classe majoritária (Pontual) do que a minoritária (Atraso), o que é comum em conjuntos de dados desbalanceados.

# %%
# Matriz de Confusão
cm = confusion_matrix(y_test_calib, y_pred)
sns.heatmap(cm, annot=True, fmt='d')
plt.title('Matriz de Confusão')
plt.show()

# %% [markdown]
# ### Curva ROC

# %% [markdown]
# A relação entre a taxa de verdadeiro positivo e a taxa de falso positivo para diferentes limiares de classificação. A curva está suave e sobe gradualmente. No entanto, uma curva ROC ideal se aproximaria mais do canto superior esquerdo mais rápido. A consequência é que temos uma alta taxa de verdadeiro positivo e baixa taxa de falso positivo. Isso devido ao banco de dados desbalanceado. O resultado nos permit dizer que ainda há um potencial de melhoria no modelo

# %%
# Gerar previsões probabilísticas para a classe positiva
y_pred_proba_pos = modelo_under_samp.predict(dtest)  # Probabilidades da classe positiva

fpr, tpr, thresholds = roc_curve(y_test, y_pred_proba_pos)

# Plot da Curva ROC
plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, label='Modelo XGBoost')
plt.title('Curva ROC', fontsize=14)
plt.xlabel('Taxa de Falso Positivo (FPR)', fontsize=12)
plt.ylabel('Taxa de Verdadeiro Positivo (TPR)', fontsize=12)
plt.grid(True)
plt.legend()
plt.show()

# %% [markdown]
# ### Curva de Precisão-Recall

# %% [markdown]
# Este gráfico é útil em situações de classes desbalanceadas e foca na relação entre precisão (quão muitos dos classificados como positivos são realmente positivos) e recall (quão muitos dos positivos reais foram capturados pelo modelo). A curva começa com uma alta precisão, mas diminui à medida que o recall aumenta, isso pode ser um sinal de que pode estar acontecendo um trade-off, ou seja, visando ter mais ou manter performance.

# %%
from sklearn.metrics import precision_recall_curve
import matplotlib.pyplot as plt

# Obter as probabilidades da classe positiva usando o modelo treinado
y_pred_proba_pos = modelo_under_samp.predict(dtest)  # Probabilidades da classe positiva

# Curva de Precisão-Recall
precision, recall, _ = precision_recall_curve(y_test, y_pred_proba_pos)

# Plot da Curva de Precisão-Recall
plt.figure(figsize=(8, 6))
plt.plot(recall, precision, label='Modelo XGBoost')
plt.title('Curva de Precisão-Recall', fontsize=14)
plt.xlabel('Recall', fontsize=12)
plt.ylabel('Precisão', fontsize=12)
plt.grid(True)
plt.legend()
plt.show()

# %% [markdown]
# ### Shap

# %% [markdown]
# O Shap nos permite compreender o peso de cada variavel para o modelo

# %%
explainer = shap.Explainer(modelo_under_samp, X_test_calib)
shap_values = explainer(X_test_calib)
shap_importance = shap_values.abs.mean(0).values
sorted_idx = shap_importance.argsort()
# Out:
# [15:26:57] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0750514818a16474a-1\xgboost\xgboost-ci-windows\src\c_api\c_api.cc:1240: Saving into deprecated binary model format, please consider using `json` or `ubj`. Model format will default to JSON in XGBoost 2.2 if not specified.
# 100%|===================| 83916/83948 [10:56<00:00]

# %%
shap.plots.bar(shap_values, max_display=25)

# %% [markdown]
# ### Calibration plot

# %%
from sklearn.calibration import calibration_curve
import matplotlib.pyplot as plt

# Prever probabilidades da classe positiva no conjunto de teste
y_pred_proba = modelo_under_samp.predict(dtest_calib)  # Probabilidades da classe positiva

# Calcular a curva de calibração
prob_true, prob_pred = calibration_curve(y_test_calib, y_pred_proba, n_bins=20, strategy='uniform')

# Criar o Calibration Plot
plt.figure(figsize=(8, 6))
plt.plot(prob_pred, prob_true, marker='o', label='Modelo XGBoost')
plt.plot([0, 1], [0, 1], linestyle='--', color='gray', label='Calibração Perfeita')
plt.title('Calibration Plot', fontsize=14)
plt.xlabel('Probabilidade Prevista', fontsize=12)
plt.ylabel('Frequência Observada', fontsize=12)
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# # Xgboos com smote 60/40

# %%
file_path_x = 'df_x_train.csv'
X_train = pd.read_csv(file_path_x)

file_path_y = 'df_y_train.csv'
y_train = pd.read_csv(file_path_y)

# %%
X_resampled.to_parquet("df_x_train_60_40.parquet", index=False, engine="pyarrow")
y_resampled.to_parquet("df_y_train_60_40.parquet", index=False, engine="pyarrow")

# Salvar em CSV
#X_train_calib.to_csv("df_x_train_calib.csv", index=False)
#X_test_calib.to_csv("df_xtest_calib.csv", index=False)
#y_train_calib.to_csv("df_y_train_calib.csv", index=False)
#y_test_calib.to_csv("df_ytest_calib.csv", index=False)

# %%
# Out:
# Distribuição de classes original:
# Classe 0: 82.96%
# Classe 1: 17.04%
# --------------------
# Distribuição de classes SMOTE:
# Classe 0: 59.88%
# Classe 1: 40.12%
# --------------------

# %%
# Carrega o arquivo Parquet
X_resampled = pd.read_parquet("df_x_train_60_40.parquet", engine="pyarrow")
y_resampled = pd.read_parquet("df_y_train_60_40.parquet", engine="pyarrow")

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
import xgboost as xgb

file_path = 'df_treinamento_modelo.csv'
df = pd.read_csv(file_path)

df = df.drop(columns =[ 'codigo_di', 'codigo_tipo_linha'])

# Transformar colunas categóricas em tipo "category"
df[list_dummies] = df[list_dummies].astype("category")

# Seleção das features preditoras (X) e variável-alvo (y)
dt_ax = df.drop(columns=["status_do_voo"])
dt_ay = df[['status_do_voo']]

# Codificação da variável-alvo
label_mapping = {'Pontual': 0, 'Atrasado': 1}
dt_ay = dt_ay['status_do_voo'].map(label_mapping)

# Codifica colunas categóricas como inteiros
label_encoders = {}
for col in list_dummies:
    le = LabelEncoder()
    dt_ax[col] = le.fit_transform(dt_ax[col])
    label_encoders[col] = le

# Segmentação em treino (85%) e teste (15%)
X_train, X_test, y_train, y_test = train_test_split(dt_ax, dt_ay, random_state=13, test_size=0.15)

#smote = SMOTE(random_state=42, sampling_strategy='not majority')
#X_smote_a, y_smote_a = smote.fit_resample(X_train, y_train)

# Segmentação adicional para calibração (75% treino / 25% calibração)
X_train_calib, X_test_calib, y_train_calib, y_test_calib = train_test_split(X_train, y_train, random_state=13, test_size=0.25)

smote = SMOTE(random_state=42, sampling_strategy=0.67)
X_smote_a, y_smote_a = smote.fit_resample(X_train_calib, y_train_calib)

# Reverter os valores transformados para o tipo "category" original
def revert_to_category(data, label_encoders, list_dummies):
    for col in list_dummies:
        if col in data.columns:
            le = label_encoders[col]
            data[col] = le.inverse_transform(data[col])
    return data

# Aplicar a reversão em X_smote_a, X_test_calib, X_test
X_smote_a = revert_to_category(X_smote_a, label_encoders, list_dummies)
X_test_calib = revert_to_category(X_test_calib, label_encoders, list_dummies)
X_test = revert_to_category(X_test, label_encoders, list_dummies)

# Para garantir que as colunas estão no tipo "category"
X_smote_a[list_dummies] = X_smote_a[list_dummies].astype("category")
X_test_calib[list_dummies] = X_test_calib[list_dummies].astype("category")
X_test[list_dummies] = X_test[list_dummies].astype("category")

# Converte os nomes das colunas para uma lista de strings
feature_names = list(X_test.columns)

# Converte os conjuntos para DMatrix
dtrain_calib = xgb.DMatrix(X_smote_a, label=y_smote_a, enable_categorical=True, feature_names=feature_names, nthread=-1)
dtest_calib = xgb.DMatrix(X_test_calib, label=y_test_calib, enable_categorical=True, feature_names=feature_names, nthread=-1)

# Converte os conjuntos para DMatrix
#dtrain = xgb.DMatrix(X_smote_a, label=y_smote_a, enable_categorical=True, feature_names=feature_names)
dtest = xgb.DMatrix(X_test, label=y_test, enable_categorical=True, feature_names=feature_names, nthread=-1)

# %%
def print_class_distribution(y, label):
    unique, counts = np.unique(y, return_counts=True)
    distribution = dict(zip(unique, counts))
    total = sum(counts)
    print(f'Distribuição de classes {label}:')
    for k, v in distribution.items():
        print(f'Classe {k}: {v/total:.2%}')
    print('--------------------')

print_class_distribution(y_train, 'original')
print_class_distribution(y_resampled, 'SMOTE')
# Out:
# Distribuição de classes original:
# Classe 0: 82.96%
# Classe 1: 17.04%
# --------------------
# Distribuição de classes SMOTE:
# Classe 0: 50.00%
# Classe 1: 50.00%
# --------------------

# %%
def hipertunnig(space):
    """
    Realiza o ajuste de hiperparâmetros de um modelo XGBoost usando validação cruzada com DMatrix.
    
    Args:
    space (dict): Dicionário contendo os hiperparâmetros avaliados pelo Hyperopt.
    
    Returns:
    dict: Dicionário contendo o 'loss' (negativo da média do AUCPR), o 'status' e as métricas adicionais (AUC).
    """
    # Configuração do modelo com os parâmetros do espaço
    params = {
        'max_depth': int(space['max_depth']),
        'gamma': space['gamma'],
        'reg_alpha': space['reg_alpha'],
        'reg_lambda': space['reg_lambda'],
        'min_child_weight': int(space['min_child_weight']),
        'colsample_bytree': space['colsample_bytree'],
        'learning_rate': space['learning_rate'],
        'max_delta_step': space['max_delta_step'],
        'subsample': space['subsample'],
        'sampling_method': space['sampling_method'],
        'tree_method': space['tree_method'],       
        'device': space['device'], 
        'enable_categorical': space['enable_categorical'],
        'scale_pos_weight': space['scale_pos_weight'],
        'eval_metric': ["aucpr", "auc"],  # Avalia AUCPR e AUC
        'objective': space['objective'],
        'seed': space['seed'],
        'random_state': space['seed'],
        'max_cat_to_onehot': int(space['max_cat_to_onehot']),
        'max_cat_threshold': int(space['max_cat_threshold']),  
        'validate_parameters': space['validate_parameters']
    }

    # Realiza a validação cruzada com xgb.cv
    cv_results = xgb.cv(
        params=params,
        dtrain=dtrain_calib,                  # DMatrix preparado
        num_boost_round=int(space['n_estimators']),
        nfold=5,                              # Número de folds
        metrics=["aucpr", "auc"],             # Métricas de avaliação
        as_pandas=True,                       # Retorna os resultados como DataFrame
        seed=42,
        stratified=True,                      # Garante estratificação
        early_stopping_rounds = 10,           # Ativa a parada antecipada
    )
    
    # Calcula a média do AUCPR e do AUC
    mean_aucpr = cv_results["test-aucpr-mean"].max()
    mean_auc = cv_results["test-auc-mean"].max()
    print("Média AUCPR: ", mean_aucpr)
    print("Média AUC: ", mean_auc)

    # Retorna os resultados
    return {
        'loss': -mean_aucpr,   # Usa o negativo do AUCPR como função de perda
        'status': STATUS_OK,
        'additional_metrics': {
            'aucpr': mean_aucpr,
            'auc': mean_auc}}

# Espaço de busca atualizado
space = {
    'max_depth': scope.int(hp.quniform("max_depth", 1, 15, 1)),
    'gamma': hp.uniform('gamma', 1, 20),
    'reg_alpha': scope.int(hp.quniform('reg_alpha', 0, 200, 1)),
    'reg_lambda': hp.uniform('reg_lambda', 0, 10),
    'colsample_bytree': hp.uniform('colsample_bytree', 0.1, 1),
    'min_child_weight': scope.int(hp.quniform('min_child_weight', 0, 20, 1)),
    'learning_rate': hp.uniform('learning_rate', 0.01, 0.5),
    'n_estimators': scope.int(hp.quniform('n_estimators', 50, 1000, 10)),
    'max_delta_step': hp.uniform('max_delta_step', 0, 10),
    'subsample': hp.uniform('subsample', 0.3, 1),
    'sampling_method': 'gradient_based',
    'tree_method': 'hist',
    'device': 'cuda',
    'enable_categorical': True,
    'scale_pos_weight': hp.uniform('scale_pos_weight', 1, 10),
    'max_cat_to_onehot': scope.int(hp.quniform('max_cat_to_onehot', 3, 50, 1)),
    'max_cat_threshold': scope.int(hp.quniform('max_cat_threshold', 3, 50, 1)),
    'validate_parameters': True,
    'seed': 0,
    'objective': 'binary:logistic'
}

# %%
# Executando a otimização
trials = Trials()
best_hyperparams = fmin(fn=hipertunnig, 
                        space=space, 
                        algo=tpe.suggest, 
                        max_evals=10, 
                        trials=trials)

# Obtendo os melhores hiperparâmetros
best_hyperparams = space_eval(space, best_hyperparams)
print("Melhores hiperparâmetros:", best_hyperparams)
# Out:
#   0%|                                                                           | 0/10 [00:00<?, ?trial/s, best loss=?]
# [18:36:18] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0750514818a16474a-1\xgboost\xgboost-ci-windows\src\learner.cc:742:
# Parameters: { "enable_categorical" } are not used.
# Média AUCPR:
# 0.9209599543298607
# Média AUC:
# 0.9217705159119994
#  10%|████▊                                           | 1/10 [00:33<04:58, 33.20s/trial, best loss: -0.9209599543298607]
# [18:36:51] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0750514818a16474a-1\xgboost\xgboost-ci-windows\src\learner.cc:742:
# Parameters: { "enable_categorical" } are not used.
# Média AUCPR:
# 0.9166075055522878
# Média AUC:
# 0.9168240570884014
#  20%|█████████▌                                      | 2/10 [00:57<03:45, 28.20s/trial, best loss: -0.9209599543298607]
# [18:37:16] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0750514818a16474a-1\xgboost\xgboost-ci-windows\src\learner.cc:742:
# Parameters: { "enable_categorical" } are not used.
# Média AUCPR:
# 0.9182591885146838
# Média AUC:
# 0.918567661802283
#  30%|██████████████▍                                 | 3/10 [01:13<02:36, 22.36s/trial, best loss: -0.9209599543298607]
# [18:37:31] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0750514818a16474a-1\xgboost\xgboost-ci-windows\src\learner.cc:742:
# Parameters: { "enable_categorical" } are not used.
# Média AUCPR:
# 0.91246464397373
# Média AUC:
# 0.9115977816458608
#  40%|███████████████████▏                            | 4/10 [01:26<01:53, 18.88s/trial, best loss: -0.9209599543298607]
# [18:37:45] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0750514818a16474a-1\xgboost\xgboost-ci-windows\src\learner.cc:742:
# Parameters: { "enable_categorical" } are not used.
# Média AUCPR:
# 0.9026004475964623
# Média AUC:
# 0.9050023259279916
#  50%|████████████████████████                        | 5/10 [01:42<01:27, 17.60s/trial, best loss: -0.9209599543298607]
# [18:38:00] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0750514818a16474a-1\xgboost\xgboost-ci-windows\src\learner.cc:742:
# Parameters: { "enable_categorical" } are not used.
# Média AUCPR:
# 0.9190543906740363
# Média AUC:
# 0.9189918754867674
#  60%|████████████████████████████▊                   | 6/10 [02:09<01:22, 20.74s/trial, best loss: -0.9209599543298607]
# [18:38:27] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0750514818a16474a-1\xgboost\xgboost-ci-windows\src\learner.cc:742:
# Parameters: { "enable_categorical" } are not used.
# Média AUCPR:
# 0.9144664835776558
# Média AUC:
# 0.9141231457277181
#  70%|█████████████████████████████████▌              | 7/10 [02:31<01:04, 21.33s/trial, best loss: -0.9209599543298607]
# [18:38:49] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0750514818a16474a-1\xgboost\xgboost-ci-windows\src\learner.cc:742:
# Parameters: { "enable_categorical" } are not used.
#
#
# [18:38:50] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0750514818a16474a-1\xgboost\xgboost-ci-windows\src\learner.cc:742:
# Parameters: { "enable_categorical" } are not used.
# Média AUCPR:
# 0.6959676847286708
# Média AUC:
# 0.7748924604800519
#  80%|██████████████████████████████████████▍         | 8/10 [02:37<00:32, 16.44s/trial, best loss: -0.9209599543298607]
# [18:38:55] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0750514818a16474a-1\xgboost\xgboost-ci-windows\src\learner.cc:742:
# Parameters: { "enable_categorical" } are not used.
#
#
# [18:38:56] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0750514818a16474a-1\xgboost\xgboost-ci-windows\src\learner.cc:742:
# Parameters: { "enable_categorical" } are not used.
# Média AUCPR:
# 0.9142225417899615
# Média AUC:
# 0.9128577031642697
#  90%|███████████████████████████████████████████▏    | 9/10 [03:01<00:18, 18.78s/trial, best loss: -0.9209599543298607]
# [18:39:19] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0750514818a16474a-1\xgboost\xgboost-ci-windows\src\learner.cc:742:
# Parameters: { "enable_categorical" } are not used.
# Média AUCPR:
# 0.8986642238220373
# Média AUC:
# 0.8995421657805451
# 100%|███████████████████████████████████████████████| 10/10 [03:12<00:00, 19.26s/trial, best loss: -0.9209599543298607]
# Melhores hiperparâmetros: {'colsample_bytree': 0.7210214022859933, 'device': 'cuda', 'enable_categorical': True, 'gamma': 4.033266282746563, 'learning_rate': 0.0974985360016575, 'max_cat_threshold': 17, 'max_cat_to_onehot': 18, 'max_delta_step': 5.0162048401116985, 'max_depth': 13, 'min_child_weight': 7, 'n_estimators': 230, 'objective': 'binary:logistic', 'reg_alpha': 42, 'reg_lambda': 0.7961284323034945, 'sampling_method': 'gradient_based', 'scale_pos_weight': 67.31835474171955, 'seed': 0, 'subsample': 0.8692472270148602, 'tree_method': 'hist', 'validate_parameters': True}

# %%
best_hyperparams
# Out:
# {'colsample_bytree': 0.7210214022859933,
#  'device': 'cuda',
#  'enable_categorical': True,
#  'gamma': 4.033266282746563,
#  'learning_rate': 0.0974985360016575,
#  'max_cat_threshold': 17,
#  'max_cat_to_onehot': 18,
#  'max_delta_step': 5.0162048401116985,
#  'max_depth': 13,
#  'min_child_weight': 7,
#  'n_estimators': 230,
#  'objective': 'binary:logistic',
#  'reg_alpha': 42,
#  'reg_lambda': 0.7961284323034945,
#  'sampling_method': 'gradient_based',
#  'scale_pos_weight': 67.31835474171955,
#  'seed': 0,
#  'subsample': 0.8692472270148602,
#  'tree_method': 'hist',
#  'validate_parameters': True}

# %%
# Carrega o arquivo Parquet
#X_resampled = pd.read_parquet("df_x_train_60_40.parquet", engine="pyarrow")
#y_resampled = pd.read_parquet("df_y_train_60_40.parquet", engine="pyarrow")

# %%
# Preparar os parâmetros do modelo
best_params = {
    'max_depth': int(best_hyperparams['max_depth']),               # Profundidade máxima da árvore
    'n_estimators': int(best_hyperparams['n_estimators']),         # Número de árvores (boost rounds)
    'reg_lambda': best_hyperparams['reg_lambda'],                  # Regularização L2
    'reg_alpha': best_hyperparams['reg_alpha'],                    # Regularização L1
    'gamma': best_hyperparams['gamma'],                            # Redução mínima da perda
    'min_child_weight': int(best_hyperparams['min_child_weight']), # Peso mínimo da folha
    'colsample_bytree': best_hyperparams['colsample_bytree'],      # Amostragem de colunas por árvore
    'learning_rate': best_hyperparams['learning_rate'],            # Taxa de aprendizado
    'max_delta_step': best_hyperparams['max_delta_step'],          # Passo máximo de atualização
    'subsample': best_hyperparams['subsample'],                    # Fração de amostras para cada árvore
    'sampling_method': best_hyperparams['sampling_method'],        # Método de amostragem (e.g., 'uniform' ou 'gradient_based')
    'tree_method': best_hyperparams['tree_method'],                # Método de crescimento da árvore ('hist', 'gpu_hist', etc.)
    'scale_pos_weight': best_hyperparams['scale_pos_weight'],      # Peso para classes desbalanceadas
    'max_cat_to_onehot': best_hyperparams['max_cat_to_onehot'],    # Número máximo de categorias para one-hot
    'max_cat_threshold': best_hyperparams.get('max_cat_threshold', 20), # Limite máximo de categorias (valor padrão incluído)
    'objective': 'binary:logistic',                                # Objetivo do modelo (logística binária)
    'eval_metric': ["aucpr", "auc"],                               # Métrica de avaliação padrão
    'enable_categorical': True,                                    # Suporte a variáveis categóricas
    'validate_parameters': True,                                   # Validação dos parâmetros
    'seed': best_hyperparams.get('seed', 0),                       # Semente para reprodutibilidade
    'random_state': best_hyperparams.get('random_state', 0),       # Estado aleatório
    'device': best_hyperparams.get('device', 'cuda'),              # Especifica o uso de GPU ('cuda' ou 'cpu')
    'verbosity': 1,                                                # Nível de logging do modelo
    'nthread': best_hyperparams.get('nthread', -1)                 # Número de threads para paralelismo
}

# Separar o número de iterações de boosting
num_boost_round = best_params.pop('n_estimators')  # Remove do dict e armazena separadamente

# Treinamento com early stopping
model_class_60_40 = xgb.train(
    params=best_params,
    dtrain=dtrain,
    num_boost_round=num_boost_round,
    evals=[(dtest, 'validation')],  # Adiciona o conjunto de validação
    early_stopping_rounds=13,      # Critério de parada
    verbose_eval=True              # Mostra o progresso durante o treinamento
)
# Out:
# [18:39:30] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0750514818a16474a-1\xgboost\xgboost-ci-windows\src\learner.cc:742:
# Parameters: { "enable_categorical" } are not used.

# %%
# Salvar o modelo
save_pickle(model_class_60_40, 'modelo/model_60_40.pkl')

# %% [markdown]
# ## Analise do Resultado

# %%
import numpy as np
from sklearn.metrics import (
    accuracy_score, confusion_matrix, precision_score, recall_score,
    f1_score, roc_auc_score, balanced_accuracy_score, average_precision_score,
    log_loss, brier_score_loss, cohen_kappa_score, matthews_corrcoef
)

# Garantir que y_test e y_pred_proba sejam arrays NumPy
y_test_np = np.array(y_test_calib)  # Converte y_test para NumPy se necessário
y_pred_proba = model_class_60_40.predict(dtest_calib)  # Previsões no formato de probabilidades da classe positiva

# Prever as classes com base no limiar de 0.5
y_pred = (y_pred_proba >= 0.5).astype(int)

# Matriz de confusão e cálculos básicos
cm = confusion_matrix(y_test_np, y_pred)
TN, FP, FN, TP = cm.ravel()
accuracy = accuracy_score(y_test_np, y_pred)
sensitivity = TP / (TP + FN) if (TP + FN) > 0 else 0
specificity = TN / (TN + FP) if (TN + FP) > 0 else 0
precision = TP / (TP + FP) if (TP + FP) > 0 else 0
recall = sensitivity
f1 = (2 * precision * recall) / (precision + recall) if (precision + recall) > 0 else 0
balanced_acc = balanced_accuracy_score(y_test_np, y_pred)
fpr = FP / (FP + TN) if (FP + TN) > 0 else 0
fnr = FN / (FN + TP) if (FN + TP) > 0 else 0

# Métricas baseadas em probabilidades
prauc = average_precision_score(y_test_np, y_pred_proba)
auc = roc_auc_score(y_test_np, y_pred_proba)
gini = 2 * auc - 1
mcc = matthews_corrcoef(y_test_np, y_pred)
log_loss_value = log_loss(y_test_np, y_pred_proba)
brier_score = brier_score_loss(y_test_np, y_pred_proba)
kappa = cohen_kappa_score(y_test_np, y_pred)

# Geometric Mean (G-Mean)
g_mean = np.sqrt(sensitivity * specificity)

# Exibir as métricas
print(f'Accuracy: {accuracy:.3f}')
print(f'Precision: {precision:.3f}')
print(f'Recall: {recall:.3f}')
print(f'F1-Score: {f1:.3f}')
print(f'PRAUC: {prauc:.3f}')
print(f'AUC: {auc:.3f}')
print(f'Gini Coefficient: {gini:.3f}')
print(f'MCC: {mcc:.3f}')
print(f'Log Loss: {log_loss_value:.3f}')
print(f'Brier Score: {brier_score:.3f}')
print(f'Cohen\'s Kappa: {kappa:.3f}')
print(f'Balanced Accuracy: {balanced_acc:.3f}')
print(f'Specificity: {specificity:.3f}')
print(f'False Positive Rate (FPR): {fpr:.3f}')
print(f'False Negative Rate (FNR): {fnr:.3f}')
print(f'Geometric Mean (G-Mean): {g_mean:.3f}')
# Out:
# Accuracy: 0.206
# Precision: 0.176
# Recall: 0.989
# F1-Score: 0.298
# PRAUC: 0.318
# AUC: 0.683
# Gini Coefficient: 0.366
# MCC: 0.065
# Log Loss: 1.988
# Brier Score: 0.623
# Cohen's Kappa: 0.012
# Balanced Accuracy: 0.517
# Specificity: 0.045
# False Positive Rate (FPR): 0.955
# False Negative Rate (FNR): 0.011
# Geometric Mean (G-Mean): 0.210

# %% [markdown]
# ### Feature Importance

# %%
plt.rcParams['figure.figsize'] = [13, 9]
xgb.plot_importance(model_class_60_40, max_num_features=20)
plt.show()

# %% [markdown]
# #### Treeplot

# %%
# plot single tree
#fig, ax = plt.subplots(figsize=(100, 100))
#fig = plt.figure(figsize=(12, 6))
plt.figure(figsize=(50, 50))
plot_tree(model_class_60_40)
#plt.savefig('xgb_treeplot.jpg', dpi=1800)  
plt.show()

# %% [markdown]
# ### Matriz de Confusão

# %% [markdown]
# O gráfico de calor mostra as previsões do modelo em relação aos valores reais. Os valores na diagonal (7979 e 148171) representam as previsões corretas para as classes negativas (0) e positivas (1), respectivamente. Os outros dois valores (19805 e 18812) representam os erros do tipo I(falsos negativos) e tipo II(falsos positivos), respectivamente. A matriz sugere que o modelo é melhor em prever a classe majoritária (Pontual) do que a minoritária (Atraso), o que é comum em conjuntos de dados desbalanceados.

# %%
# Matriz de Confusão
cm = confusion_matrix(y_test_calib, y_pred)
sns.heatmap(cm, annot=True, fmt='d')
plt.title('Matriz de Confusão')
plt.show()

# %% [markdown]
# ### Curva ROC

# %% [markdown]
# A relação entre a taxa de verdadeiro positivo e a taxa de falso positivo para diferentes limiares de classificação. A curva está suave e sobe gradualmente. No entanto, uma curva ROC ideal se aproximaria mais do canto superior esquerdo mais rápido. A consequência é que temos uma alta taxa de verdadeiro positivo e baixa taxa de falso positivo. Isso devido ao banco de dados desbalanceado. O resultado nos permit dizer que ainda há um potencial de melhoria no modelo

# %%
# Gerar previsões probabilísticas para a classe positiva
y_pred_proba_pos = model_class_60_40.predict(dtest)  # Probabilidades da classe positiva

fpr, tpr, thresholds = roc_curve(y_test, y_pred_proba_pos)

# Plot da Curva ROC
plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, label='Modelo XGBoost')
plt.title('Curva ROC', fontsize=14)
plt.xlabel('Taxa de Falso Positivo (FPR)', fontsize=12)
plt.ylabel('Taxa de Verdadeiro Positivo (TPR)', fontsize=12)
plt.grid(True)
plt.legend()
plt.show()

# %% [markdown]
# ### Curva de Precisão-Recall

# %% [markdown]
# Este gráfico é útil em situações de classes desbalanceadas e foca na relação entre precisão (quão muitos dos classificados como positivos são realmente positivos) e recall (quão muitos dos positivos reais foram capturados pelo modelo). A curva começa com uma alta precisão, mas diminui à medida que o recall aumenta, isso pode ser um sinal de que pode estar acontecendo um trade-off, ou seja, visando ter mais ou manter performance.

# %%
from sklearn.metrics import precision_recall_curve
import matplotlib.pyplot as plt

# Obter as probabilidades da classe positiva usando o modelo treinado
y_pred_proba_pos = model_class_60_40.predict(dtest)  # Probabilidades da classe positiva

# Curva de Precisão-Recall
precision, recall, _ = precision_recall_curve(y_test, y_pred_proba_pos)

# Plot da Curva de Precisão-Recall
plt.figure(figsize=(8, 6))
plt.plot(recall, precision, label='Modelo XGBoost')
plt.title('Curva de Precisão-Recall', fontsize=14)
plt.xlabel('Recall', fontsize=12)
plt.ylabel('Precisão', fontsize=12)
plt.grid(True)
plt.legend()
plt.show()

# %% [markdown]
# ### Shap

# %% [markdown]
# O Shap nos permite compreender o peso de cada variavel para o modelo

# %%
explainer = shap.Explainer(model_class_60_40, X_test_calib)
shap_values = explainer(X_test_calib)
shap_importance = shap_values.abs.mean(0).values
sorted_idx = shap_importance.argsort()

# %%
shap.plots.bar(shap_values, max_display=25)

# %% [markdown]
# ### Calibration plot

# %%
from sklearn.calibration import calibration_curve
import matplotlib.pyplot as plt

# Prever probabilidades da classe positiva no conjunto de teste
y_pred_proba = model_class_60_40.predict(dtest_calib)  # Probabilidades da classe positiva

# Calcular a curva de calibração
prob_true, prob_pred = calibration_curve(y_test_calib, y_pred_proba, n_bins=20, strategy='uniform')

# Criar o Calibration Plot
plt.figure(figsize=(8, 6))
plt.plot(prob_pred, prob_true, marker='o', label='Modelo XGBoost')
plt.plot([0, 1], [0, 1], linestyle='--', color='gray', label='Calibração Perfeita')
plt.title('Calibration Plot', fontsize=14)
plt.xlabel('Probabilidade Prevista', fontsize=12)
plt.ylabel('Frequência Observada', fontsize=12)
plt.legend()
plt.grid(True)
plt.show()
